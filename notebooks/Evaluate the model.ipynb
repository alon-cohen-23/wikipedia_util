# %% [markdown]
# ## Load The modules

# %%
from pathlib import Path
import numpy as np
import pandas as pd
from comet import download_model, load_from_checkpoint
from huggingface_hub import login
import torch
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
# Out:
# /anaconda/envs/translator/lib/python3.11/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: '/anaconda/envs/translator/lib/python3.11/site-packages/torchvision/image.so: undefined symbol: _ZN3c104cuda9SetDeviceEi'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(

# %% [markdown]
# ## Load The model to evaluate

# %%
model_name_or_path = "./models/dekel-cp-124998-and-fauda-teheran-inss/"

src_lang = "heb_Hebr"
col_src = 'he'
dst_lang = "eng_Latn"

model = AutoModelForSeq2SeqLM.from_pretrained(model_name_or_path, torch_dtype=torch.float16).to("cuda")
tokenizer = AutoTokenizer.from_pretrained(model_name_or_path, src_lang=src_lang)
#model = model.to_bettertransformer()
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %% [markdown]
# ## Load the data to Test on

# %%
NUMBER_OF_SAMPLES = 100

DATA_TO_LOAD_INSS = Path('./tr_data/inss/validation.parquet')
DATA_TO_LOAD_TEHERAN = Path('./tr_data/teheran/validation.parquet')
DATA_TO_LOAD_FAUDA = Path('./tr_data/fauda/validation.parquet')


df_teheran = pd.read_parquet(DATA_TO_LOAD_TEHERAN)
df_inss = pd.read_parquet(DATA_TO_LOAD_INSS)
df_fauda = pd.read_parquet(DATA_TO_LOAD_FAUDA)

df_samp = pd.concat([df_teheran, df_inss, df_fauda])

# %%
df_samp
# Out:
#                                             translation
# 1394  {'en': ' Give her a few hours, she'll be fine....
# 353   {'en': ' The Zionists must be planning somethi...
# 1334  {'en': ' Who sent you here, the guards?', 'he'...
# 906   {'en': ' The door is stuck, but don't worry.',...
# 1290  {'en': ' We have no way of knowing that.', 'he...
# ...                                                 ...
# 7475  {'en': ' You are our family, Doron.', 'he': 'א...
# 2236  {'en': ' Abu Ahmed sent me.', 'he': 'אבו אחמד ...
# 8932  {'en': ' We'll talk about that later.', 'he': ...
# 400   {'en': ' I'm sure they will be happy.', 'he': ...
# 3919  {'en': ' thought it would fix her, straighten ...
#
# [16819 rows x 1 columns]

# %% [markdown]
# ## Translate

# %%
def predict(tokenizer, model, df_samp, col_src='he', dst_lang="eng_Latn", batch_size=500):
    src_texts = []
    for index, row in df_samp.iterrows():
        src_texts.append(row['translation'][col_src])

    # Split the texts into batches  
    translated_texts = []
    batches = [src_texts[i:i + batch_size] for i in range(0, len(src_texts), batch_size)]
    for batch in batches:
        inputs = tokenizer.batch_encode_plus(batch, return_tensors="pt", padding=True).to("cuda")
        translated_tokens = model.generate(**inputs, forced_bos_token_id=tokenizer.lang_code_to_id[dst_lang])
        translated_texts += tokenizer.batch_decode(translated_tokens, skip_special_tokens=True)[:]
    return translated_texts


translated_texts = predict(tokenizer, model, df_samp, col_src=col_src, dst_lang=dst_lang)
df_samp['pred'] = translated_texts

# %%
translated_texts
# Out:
# ["Give her a few hours, she'll be fine.",
#  'The grades must be planning something big.',
#  'Who sent you here, the shifts?',
#  "The door is stuck, but don't worry.",
#  'We have no ability to know that.',
#  'So we are operating from route A-301.',
#  'You took the goods and disappeared.',
#  'How soon do they unload?',
#  "Well, that's a big load.",
#  'But from now on, you work for me.',
#  'I have to go do something in the field.',
#  "But I don't want you to die of disease.",
#  'let me talk to her',
#  'It started as an artist commune, but now all kinds of guys live here.',
#  'You owe it to my mother.',
#  'No need to talk about it.',
#  'Let my family go.',
#  'We begin boarding, please proceed to the gate, thank you.',
#  "That's why this is our main goal.",
#  'If one of us talks to Farham, it will only scare him away.',
#  'Maybe one of my employees had a meeting at the electric company that evening.',
#  'I worked at the electric company but left.',
#  "Just ask him what's going on.",
#  'He is an important man who likes to get high.',
#  '"He said you should work "secretly.',
#  'SONG: Listen to what I saw in the bathroom.',
#  'Is this Mr. Massud Tabrizi?',
#  'how did you do it',
#  "They found me at a friend's house, where I was staying.",
#  "But that's not what I know.",
#  'Maybe you have a guest at home?',
#  "But I don't want you to forget me.",
#  'The day they left, you swear to me that you will sever all contact with them permanently.',
#  'Do you think he will do it?',
#  "They say you work with the Israelis, who are the ones who paid for Ms. Nahid's surgery.",
#  "In God's name, we will and we will succeed.",
#  "I'm not in a position to get on a plane right now.",
#  'I had a really long day, then.',
#  "that you don't want your children to grow up in a country like this.",
#  'I spoke to the taxi driver who picked her up.',
#  "I'm not even sure it's her, because",
#  "He didn't get out of here.",
#  'So you know what to do?',
#  'There are parties here, live performances.',
#  'The operation tonight includes scanning the final access points to the target, and installing technological measures for the landing of explosive devices tomorrow.',
#  'He knew too much, Tamar.',
#  "I'll leave soon and come back for the evening to get my things.",
#  'My agent is very reliable.',
#  'He was convicted in absentia of oil-related finances.',
#  'I let him go to see if he made a mistake.',
#  'Anyway, the planes took off.',
#  'Now I understand why.',
#  'Would you like to book another flight today, sir?',
#  'User name -: - :Password - Entry approved - Stored, corpse!',
#  "You know, it's an old military base.",
#  "No, it's nothing.",
#  "I don't know either.",
#  "We've already come this far, it's time to do it.",
#  'I want to report to the Prime Minister that the planes can carry out their mission tonight quietly, that the pilots have someone watching over them.',
#  "Didn't you say they are sitting down to eat now?",
#  "Okay, in 20 minutes you'll find a way to go down without Milad noticing.",
#  'can i go to the bathroom',
#  'He threatened your life.',
#  'Look at the city lights.',
#  '- Locked on me, maneuvering.',
#  'So your alligator tears were just for the girl?',
#  "That's much better.",
#  'Maybe one of the guys has a key.',
#  "I'm not from the Mossad or anything, I just flew to India.",
#  'Just, Karim and his nonsense.',
#  'I just wanted to feel your body.',
#  "You must be Erzo's daughter.",
#  'When he decides something, there is no one to talk to.',
#  'I love my homeland more than you think.',
#  'You can leave your details and we will call you.',
#  '- Abtsam Abdullah Ibrahim in Dran - Get up.',
#  'I will execute Mordecai.',
#  "That's why I contacted you.",
#  'My daughter knows nothing.',
#  'You have to bypass it - what do you write there?',
#  'He was a bank manager.',
#  'This is the real Zilla Gorbanipar.',
#  'Send me a detailed report and transfer the case to the Ministry of State Security.',
#  'I only did it for my daughter.',
#  'Our best people are on it.',
#  'Well, he took care of our mobile, corrupted the signal, connected through a remote hub in the Stockholm area.',
#  "So it's better if I tell them you can't do it?",
#  'No, but we are narrowing the options.',
#  'Why did he yell at you?',
#  'He knows too much.',
#  "What's wrong with your friend?",
#  'We need you to follow some instructions.',
#  'Come home by tomorrow afternoon.',
#  "And that's where I met my husband.",
#  '- Ababil Technical Complex, Tehran - Great game.',
#  'He is mentally unstable.',
#  "With God's help, the day after tomorrow we will see and hug.",
#  "I'll explain everything to you when we meet, okay?",
#  'So you are in charge here.',
#  'You let your feelings jeopardize this whole operation.',
#  'For months the cancer ate away at her beautiful body.',
#  "It has to do with your husband's job.",
#  "I hope I'm not bothering you.",
#  'You should have counted first.',
#  "I can't, Mr. policeman.",
#  'They asked me to tell you that you did the right thing and that if you continue like this, we will see you soon.',
#  'I chose to close my eyes.',
#  'Almost at the level of a native tongue, but she also had a bit of a foreign accent.',
#  'My family is already in danger.',
#  'The people who serve the big devil and the little devil, America and the Zionists.',
#  '"And where is she now, "Tamar Rabinian?',
#  'I wish my parents would come visit me.',
#  'I tell you this calmly.',
#  'So we owe Milad.',
#  'I was sure you were arrested.',
#  'Sorry, it went on a bit.',
#  'Nahid, my wife, forced me to stop.',
#  "It's less predictable, isn't it?",
#  'We will let them think that we are looking for an Iranian citizen.',
#  'So Arzo told you everything.',
#  "Hey, wait, don't touch it, stop.",
#  'Last night she boarded a return flight.',
#  'Ask Mohsen, he worked there.',
#  "I'm in the student's bay.",
#  "You can put your clothes in the basket, I'll wash them for you.",
#  "This is Tehran's secondary power plant.",
#  "It's a type of doris chicken.",
#  'We need more girls to come!',
#  "Because if that's the case, it's the end.",
#  'I have nowhere to go.',
#  "So I'm telling you, if anything happens to him, it will be your responsibility.",
#  'What I tell you stays between us.',
#  'You know the penalty for such a thing.',
#  'This regime is shitting all over the country.',
#  'For your life, and for the lives of your wife and children.',
#  'You have every right to be mad at me.',
#  "I haven't touched a cigarette in five years.",
#  'Now take out the scanner.',
#  'Haley, inform the MIA that the planes are exposed to the Iranian radar.',
#  'Far from our dear country, living in a new country, these are the things that killed her.',
#  'So why are you leaving?',
#  "Do you think I can break a man's neck?",
#  "Didn't you hear my message?",
#  'Perform a lockdown disconnection from TKA.',
#  'You have to believe me.',
#  'No money, no employment.',
#  'Have you seen her by chance?',
#  'Faraz, your wife is receiving the best medical care possible.',
#  'The plane has not yet landed.',
#  "I don't know all that, because",
#  "But it takes courage, doesn't it?",
#  'We wandered in the mountains once, we took a trip and we totally got lost, and.',
#  'My father, your grandfather.',
#  'Say, Milad said that his girlfriend worked at the electric company?',
#  "I'll tell you what I think.",
#  'She got there by mistake.',
#  'Reformists, conservatives, the story is over!',
#  'Report the malfunction again.',
#  'what is this place',
#  "Places he wasn't supposed to surf.",
#  'What were you doing at these two murder scenes, that night, two hours apart?',
#  "She didn't snitch on anyone.",
#  'What happened to the stewardess?',
#  'Hello, Muncher, how are you?',
#  "He's not just drugged.",
#  'We intended to release her in the next few days.',
#  'What about your family?',
#  'how long have you known me',
#  "We'll be with you in three minutes.",
#  'I will bring them anywhere in the world you want to live, but you must leave Iran now.',
#  "Forgive me, sir, but I hope that's not what you think of me.",
#  'Dr. Torbati to the pediatrics department.',
#  'This picture is what the Hamas in Israel broadcasts.',
#  'We were in a relationship for a few months, and then the connection went haywire.',
#  'Works for the judiciary named Dariush.',
#  'I hope you will come back to us soon.',
#  "I've been working at the electric company since we got back from Qatar.",
#  'And it went well for her, no doubt.',
#  'Check all the stations in the district.',
#  'Do you want me to show you the background check they did on you?',
#  'I would darken the whole city.',
#  'I thought if there was a power outage somewhere.',
#  '- Ali: Check at 13 Istiqlal Street - there are people inside.',
#  'Her difficulties, our difficulties.',
#  'You have to stay like this until the flight.',
#  'I went to take care of what you asked for.',
#  'Three, maneuvering operation, strong breaker.',
#  'Then go set yourself on fire.',
#  "Let's eat before Ibrahim arrives.",
#  "And I'm leaving Iran, then.",
#  "I don't know, it's",
#  'The mother looks at them and says, "!right" "?He says, "Wow, mom, how did you know"! She replies, "Because I already hate her.',
#  'Why did you even bring her?',
#  'Are these the same passengers who boarded in Jordan?',
#  'A flight from Jordan made a forced landing at our place.',
#  'Looks like some kind of black bird.',
#  'Are you going to board another flight today?',
#  'Is that he who directed you there?',
#  'How do you know Mr. Massoud Tabrizi?',
#  'The main thing is to get rid of them as quickly as possible.',
#  'I just follow orders.',
#  'Check it immediately.',
#  'Want me to take you there?',
#  'And what about the money I gave you?',
#  'You have something to work with.',
#  'Also check the security tape.',
#  'All the characters and events presented in the series - are completely fictitious - any resemblance to real events or people -, -, alive or dead - is absolutely accidental - good morning.',
#  'Drink a glass of water, relax and then call me.',
#  'I pray you find a place in your heart to forgive me and come.',
#  'Sir, this woman is bothering me.',
#  'Where did you learn to cook like that?',
#  'I have a last name, the Aziz family.',
#  "She's not a liar, but she should mind her own business.",
#  'What happened, you whore?',
#  'This is your last warning.',
#  "Come on, I'll walk you out.",
#  "I can't risk him.",
#  'I want to deal them a blow that will bring them down on all fours.',
#  'I was born here, but I grew up in Qatar and moved back here two years ago.',
#  'why are you calling me',
#  'Go hug your family.',
#  "No, I don't think so.",
#  'I gave him a few more blows.',
#  'Every time I looked at him, I felt like I was looking at one of the boys in the neighborhood.',
#  'Your video was just the beginning.',
#  'Send your team.',
#  'Does anyone come here often?',
#  "- There was an officer from my base there. -?June: Say, you've gone completely insane - Good.",
#  'My friend was murdered before my eyes.',
#  'Thank you very much for everything.',
#  'How long until we have control of the radar?',
#  'We will not have another chance.',
#  'Milad, stop thinking out of your dick!',
#  'Why did you leave anyway?',
#  'Your name has been transferred to all the border stations, and even if you somehow manage to get out, as soon as your foot steps outside Iran, my first visit will be to this house.',
#  'May the good and generous God keep her.',
#  'Here, Madam Kamli, your carriage has arrived.',
#  'I told you this app is worth nothing.',
#  "Trust me, I've tried every other way.",
#  'Unemployment, workers who have not yet been paid, and students who are in prison.',
#  'You are in a senior position in the justice system.',
#  'do you know how to use it',
#  'do you really want to go home',
#  "You just burned a month's worth of work for me, damn it!",
#  'I gave you a chance, it ended in total loss.',
#  'how do you know her',
#  'The place is manned 24/7, there are technicians there.',
#  "Anyway you're going to kill me in a moment, aren't you?",
#  "Because I'm not doing it again.",
#  "No, she and my father didn't really get along there.",
#  'Me and my damn job.',
#  "Explain to me how it could be that you argued, he chased you out, yelled at you, you didn't answer, you left, and then someone else broke his neck and left?",
#  'In 42 minutes they reach the Kurdish border with Iran and from there, 31 minutes to execute.',
#  'I will give you an answer today.',
#  'I want to talk to him.',
#  "You can't come in.",
#  'Do you know what a mess I would have at work if anyone knew she was at our house?',
#  'He had a sentence he would say all the time.',
#  'From the beginning she seemed suspicious to me.',
#  "Anyway, I think it's impossible for me.",
#  'I understand that you came here by mistake.',
#  'I thought I recognized her handwriting.',
#  'So why did you lie in the investigation?',
#  "I'd rather die than help you.",
#  '"Your death should have a purpose.',
#  'It looks better to me.',
#  "I don't want them to know we're looking for their agent.",
#  "I'll get on the first plane tomorrow.",
#  'Is she in a position to go back in?',
#  "that it's fun to be a refugee?",
#  'He has to do it himself.',
#  'And then, instead of arguing with me, she just started singing a song to me.',
#  'We need everyone who can come.',
#  'Hallie, report to the Air Force.',
#  "Are you sure the Israelis don't know?",
#  "Maybe one day I'll do it for you.",
#  "No matter what happened to me, I wouldn't put your family at risk.",
#  'Jilla is a good soul.',
#  'The entire route is now covered in cameras.',
#  "Revolutionary Guards Frustrating Intelligence Headquarters -, - Tehran I just need to update the permissions and I'm done.",
#  "I can't believe you let him go.",
#  'Make sure that Saoud Tabrizi arrives in Istanbul unharmed within 24 hours.',
#  'All the characters and events presented in the series - are completely fictitious - any resemblance to real events or people - -, alive or dead - is absolutely accidental - razia.',
#  "I can't talk to you about it.",
#  'Your heart is in the right place.',
#  'So what do you say about the nuclear agreement?',
#  'We got married and decided to return to Tehran.',
#  'Slowly enter.',
#  'There were no problems.',
#  'We have to close the gate, everyone is on the plane waiting.',
#  "You shouldn't have done that.",
#  'That was our song.',
#  '- Tehran - - Tehran Revolutionary Guards Frustrating Intelligence Headquarters - Go.',
#  'These waste electricity like bitcoin miners.',
#  'Is this how she lowers her profile?',
#  'You were right, boss, there was a tradeoff.',
#  'Sorry, I have to answer.',
#  'They treat me well.',
#  'Come on, come on, give me a hug.',
#  'I see you are looking for evidence.',
#  'The clean streets of Tehran will not be allowed to be polluted.',
#  'I made us dinner.',
#  'At this time of night you must have an entrance permit.',
#  'I just want to sleep.',
#  "Your name isn't Zahra, is it?",
#  'I need to get approval.',
#  'A saint, we need him.',
#  'Are you starting with that again?',
#  'Hossaro, take him into custody.',
#  'You know what I told Masoud.',
#  'Come, we left for you too.',
#  "No one can know I'm here.",
#  'I want to come to you, to Israel, but they said in the embassy that I am not Jewish.',
#  'Holy, it looks like a line of backup singers.',
#  'Not even one day!',
#  'This is the municipal system that controls all the cameras in the area.',
#  'When I arrived in Jerusalem for the first time and saw the Holy Wall and the walls built by the Muslims, I broke down in tears.',
#  'Nahid, you have to believe me and explain this to your husband.',
#  'The engineer from the electric company identified the girl.',
#  'tell you the truth.',
#  "I'm worried because of the price of the necklace you're looking at.",
#  'Listen, a few sales and it will be behind us.',
#  'It is so beautiful to you.',
#  'I think he went back in.',
#  'It is possible that foreign parties are trying to break into these servers and enter military systems.',
#  'Khamenei is our leader, he is the successor of the Prophet.',
#  'Magdel, can you hear me?',
#  'What if they arrested you?',
#  'Good morning to you too.',
#  'As a representative of the company, I am obliged to conduct a tour of the house, to make sure that the photos you uploaded correspond to the given situation.',
#  'How did this even happen?',
#  'Go up and tell them to tone down the music a bit.',
#  'When you arrive at the safe house, activate an evacuation procedure and have Muhammad get rid of the Iranian guy.',
#  'Pervez was arrested a week ago.',
#  'The surgery will start in two hours.',
#  "But we're unemployed, and these degrees suck.",
#  'I will only stay one night.',
#  'They summoned him for some trouble.',
#  'Some things are not saved.',
#  "I can't promise you that.",
#  'He will never let anything happen to you.',
#  "It's been almost two years since we returned.",
#  "I don't know, but it was too easy.",
#  'As I said, your wife is in good hands.',
#  'For those who want to turn the university into the toilet of the capitalists.',
#  'They told me that you kidnapped someone, an Israeli citizen, and that you threatened to kill him.',
#  'The Israelis have eyes and ears in Tehran.',
#  "Haley, tell the MPA to continue, we'll stand on time.",
#  'You are just like the criminal Revolutionary Guards.',
#  'Who do you work for, Yasmin?',
#  'Did you go to the doctor I recommended to you?',
#  'wanted to update you that we are not the only ones looking for the princess.',
#  'Put her in the car and fly away.',
#  'His disruptor is activated, there is still no reconfiguration of the call.',
#  'If you answer me this question.',
#  "Is there any chance that Faraz's people got there because of you?",
#  'You have to promise me, Gorb, that you will protect my wife and children.',
#  '- You contact your source now, and convince him to let us into the NIM base tonight.',
#  'There is a situation where we will get a green light tomorrow.',
#  'I should have flown with you, I should have taken care of you.',
#  "He was at Kaiser's apartment today.",
#  'Why did he do this?',
#  'But before I could do anything.',
#  'He harassed Jilla.',
#  'who did this to you',
#  'Send two teams to follow him.',
#  'Do you know how many stories like this I hear every day?',
#  "The other girl is probably the agent we're looking for.",
#  'did you cook all this',
#  'Come on, tell me one.',
#  'You remember them, yes?',
#  "You should be thankful he's still alive.",
#  'Sorry to say, but you have a bit of an accent.',
#  '"This is a great place to party".',
#  'Feels so good.',
#  'Well, then what is this secret thing you need from me?',
#  'Mrs. Sultan, have a safe trip.',
#  'They see the planes.',
#  '- Istanbul, Turkey - Good morning, sir.',
#  'We are still trying to find out where he went from the airport, but we assume to one of the hotels in Istanbul.',
#  'The radio and TV stations are there.',
#  "I'll call you later.",
#  'Just tell me if you can get me or not.',
#  'But when I went to Israel, I felt like a stranger.',
#  "She's a good girl, a little chicken.",
#  'She said it was only for the night.',
#  'The object is driving towards the student demonstration.',
#  "Go to row R-6, it's at the southern end.",
#  'It was written in heaven.',
#  'Fahram cancelled the report of the malfunction.',
#  "I don't think I can help you.",
#  "I'm trying to save you.",
#  "Look where he's going.",
#  'It is an honor, sir.',
#  "Let's show them who we are.",
#  '"They know about "the princess.',
#  "I understand it's urgent.",
#  'Where did you even get it?',
#  'But I have good jokes.',
#  'Groups are connected to each other.',
#  'Tell them I am from the Revolutionary Guards intelligence.',
#  'Do it fast.',
#  "I can't do it for you.",
#  'Eyes only at me from now on.',
#  'How about one hour?',
#  'Milad is a computer man.',
#  'But I forwarded a copy to our cyber department and in a few hours we will be able to understand what she was trying to do there.',
#  'I have a family, I have a girl.',
#  'We tried every possible approach, but he denied having any connection to the institution.',
#  "I'm looking for my daughter.",
#  'The thing with the cameras, I fell for it.',
#  'Hassan said they would not do anything to them.',
#  "Shaheen, what's going on here?",
#  "Let's smoke something and screw our heads up.",
#  "Keep it, it's fine.",
#  'Talk to his heart, but not from your heart.',
#  '"Most people just say "hello.',
#  "We're already getting there.",
#  'Tamar, grab his legs.',
#  'He really canceled it.',
#  'I told you everything would be fine.',
#  'He left you a letter in which he explains everything.',
#  'Serial number of the air conditioner.',
#  'He was one meter from her!',
#  'In any case, we must be ready for action at any given moment.',
#  "Even though I'm the one who's chained to the bed, of the two of us, I'm free.",
#  'It hurts me that you are speaking on their behalf.',
#  'She studied there at a school for foreigners.',
#  'where are you taking me',
#  "I don't cook as much as I used to.",
#  '- Lelah Park - - Tehran University of Medical Sciences - Are you from the police?',
#  'when do i come home',
#  "I mean you're free to go.",
#  "Now it's your turn to prove it to me.",
#  'I will buy for a million tomans, if the goods are good.',
#  'I was in exactly the same situation.',
#  'Voir Hute, Voir Hute, a thousand feet below me, northeast.',
#  'what did she do to you',
#  'I knew it would have a price.',
#  'You sat in the room with him.',
#  'Remind me, where do you live?',
#  'Tamar, it\'s me, "The Eagle.',
#  "We'll talk about everything soon, okay?",
#  'My sister sent you to me.',
#  "Don't distribute that video.",
#  'I hit him and he folded.',
#  'Nothing, she kicked me in the balls.',
#  "Why can't you understand that?",
#  'You know very well what I am.',
#  'Tell the girls to come, not the boys.',
#  "You're at the airport with your wife on the way to Paris, aren't you?",
#  'Do what we tell you.',
#  'let me help you',
#  "It's really me, Kolocha.",
#  'I need him in the server room.',
#  "And don't listen to anyone.",
#  'why did you do that?',
#  "Because he won't let us work.",
#  "I don't believe a word that comes out of your mouth, and there's no way I'm helping you with anything anymore!",
#  "It's one of Farraz Kamli's pseudonyms.",
#  "You've heard them all.",
#  'She kept thinking about you.',
#  'It was one night, they deported her when they heard.',
#  'how do not you understand this?',
#  'She just came in and jumped?',
#  'My head started to hurt.',
#  "If you don't do it, I will.",
#  'We had a flat tire on the way.',
#  'She must not tell them about it.',
#  'Because you will never see them again.',
#  'I finish here and next.',
#  'What was she even looking for there?',
#  "Well, I'll keep packing.",
#  "Let's move on to the entrance path.",
#  'She returns to her family in Qatar.',
#  'I saw him also last night, chasing the princess.',
#  'do you want something to drink',
#  'Would you rather we speak English?',
#  'The surgery will go well tomorrow, inshallah.',
#  'A narrow window of opportunity has been created.',
#  'It turns out that some of the servers at the station are connected to military systems.',
#  'You have long lost your conscience.',
#  "- Don't say anything about what happened to him - Sarah Fahramand!",
#  "His wife's name is Erzo, they're 50 and something.",
#  'We could have solved it another way.',
#  'Sir, my daughter, she just messes with the computers.',
#  'This is not a good time, bro.',
#  "A fight over work doesn't look like that.",
#  'He is not pleasant to me either.',
#  '- Tehran - wait here.',
#  "The system, I can't find it.",
#  "If you help me with something tomorrow, I'll get you your passport.",
#  'We came to do a software review and update.',
#  'The world belongs to us, enough already!',
#  'Also check the balcony.',
#  'We expelled her after the demonstration.',
#  'With one click I send it to your boss.',
#  "Maybe we'll find my family.",
#  'I swear I will bring you home.',
#  'He has a travel agency.',
#  "You just don't understand the situation you are in, the capabilities of the organization that stands behind me.",
#  'Some are cheap off-the-shelf products and others are improvised.',
#  'It must take into account the possibility that in the not too distant future the organization will act directly or through its partners against Israeli and Jewish targets, both in Israel and abroad.',
#  'The traditional perception and the recipes that require change',
#  '/ Ofir Winter and Ayel Razi-Nob',
#  'Opinion suggests that a significant part of the cadres fighting in the various arenas of jihad around the world, and in particular those currently in Syria and Iraq, may eventually choose to integrate into Al-Qaeda.',
#  'This is especially true in light of the recurring possibility of a security deterioration against the background of sensitive issues such as Jerusalem and the holy places.',
#  'This is in addition to worrying trends that are already taking place, including demographic and political changes in the United States and the growing distance between the Jewish communities there and Israel.',
#  'As for the second question, the assumption is that Egypt will have an interest in preventing arms smuggling through the Rafah crossing.',
#  'Hussauna made no secret of his views that banning Hamas in Jordan in 1999 was a mistake, and he maintained good relations with the Muslim Brotherhood.',
#  'Prior to 2019, no suicide attacks were carried out in this country by Islamist organizations identified with the Salafi-Jihadi movement.',
#  'Did he have the courage to do so?',
#  'If demands are made towards Iran, some voices say, then what about Israel?',
#  'Changes in the political power structure',
#  'But after seven years of war, in which over half a million people were killed and millions of refugees and displaced, the Syrian people deserve more committed international support.',
#  'In a speech given following the mobilization of the Luzhan girls, President Obama mentioned the fact that the number of active centrifuges in Iran has increased significantly since he took office.',
#  'Therefore, they ask to maintain parallel relations with Iran and settle divisions with it through negotiations.',
#  'This was the first visit by an Iranian president to the continent in 11 years, and he described it as "a journey to widen the Iranian strategic depth".',
#  'Also, Iran prevented IAEA inspectors from visiting the natural uranium/heavy water reactor under construction at the Arak site.',
#  'The Bayraktar TB2 is an effective weapon against the Russian army.',
#  'According to their philosophy, they are only loyal to the protection of the country if the country preserves what they consider to be its democratic values.',
#  'He offers an intermediate solution.',
#  'Classifies content that needs to be removed according to its negative effects.',
#  'Another point of dispute between Azerbaijan and Iran is the issue of the division of territorial waters in the Caspian Sea.',
#  'This article will examine the significance of lifting the restriction on the sale of weapons systems to Iran.',
#  'According to the survey, 22 percent of the tourists were Jews, about 68 percent were Christians, and the rest - Muslims, members of another religion or no religious affiliation.',
#  'The equal gap ("today is filtered by tomorrow from a terrorist") between infiltration from a migrant worker and infiltration by terrorists is also wrong.',
#  'A serious public discussion should focus on several key issues.',
#  'Therefore, hosting a summit is primarily a ceremonial event, which provides the host country with public prestige and sometimes some political gain.',
#  'Firstly, the TecSAR satellite is a satellite that uses Synthetic Aperture Radar (SAR) technology to provide images of the ground surface.',
#  'Some also argue that a new axis is currently being formed between Turkey, Syria and Iran on the basis of their common interests regarding the future of Iraq.',
#  'This move, if fully implemented, will have significant budgetary implications.',
#  'Alongside these figures, the campaign also included issues related to national politics, and in particular the way the country is governed by the president and his party.',
#  'The outline of the deal was presented as a new paradigm for resolving the conflict and designing a new Middle Eastern architecture, based on an Arab-American-Israeli coalition.',
#  'This is not the end of a crisis, but in the middle of it.',
#  'The intervention should be focused on the employees, companies and industries that have been hit the worst, especially in terms of the impact on demands.',
#  "Tehran's concern stems from the scientific reality of the alternative of taking advantage of the Russian-American divide in its favor.",
#  'In addition, a dedicated team should be established to examine ways to assist the elderly population, which in any case will be the last to be released from quarantine.',
#  'The virus outbreak aggravates the crisis that Lebanon has been caught up in due to its difficult economic and fiscal situation.',
#  'Turkey-United States relations have recently faced two significant challenges.',
#  'In a wide-scale attack scenario, it will also be possible to attack land, air and sea forces as well as advanced weapons.',
#  'Despite the current political circumstances in Israel, his appearances are inconvenient for many.',
#  'Chapter Two: The Northern Arena',
#  'Such a reference is also not perceived as a purely semantic matter.',
#  'During the visit, a draft strategic cooperation agreement between the two countries was exchanged, including a clause on military-technical cooperation.',
#  'They require non-American companies to get a U.S. export license for items that were not made in the United States.',
#  'Also as far as the main and most important issue for Tehran is concerned  the lifting of sanctions  much progress has been made.',
#  'In any case, the determination model should not be determined by merely calculating costs.',
#  'Against the background of the widespread assumption that Lebanon was immune to the events of the "Arab Spring" so far, this violent escalation came as a surprise to many observers.',
#  "The Police Order (updated September 2001), defines the soldier's purpose and tasks as follows:",
#  'While 54 percent of men over the age of 45 who graduated from Haredi education studied English, only 18 percent of men aged 18-24 did so.',
#  'The weakness of the agreement lies in the fact that it is a "shed agreement" and in the need for it to be adapted in the future to the reality that will prevail in the field.',
#  'In the last year, various plans were formulated and bodies were established to deal with violence and crime in Arab society:',
#  '[7] Representative applications reviewed in this study and their relevance to victims of violence by a spouse are detailed in Chapter B.',
#  'It is necessary, therefore, to make a careful cross-section between images of objective victory and images of subjective victory.',
#  'Difficulty measuring the impact of events in the digital arena',
#  "It does demonstrate capabilities, but it also deepens the United States' position in the eyes of Iran and in its own eyes as a risk-averse actor.",
#  'This, as a step in the process aimed at putting the resistance on the path of the arrangements that complement the existence of Israel.',
#  'Iran in Iraq: A Strategic Area of Influence',
#  'However, it is not yet clear whether there will be a majority of the proposal among the members of the council and how the United States will conduct the vote at the security council.',
#  'The Turkish position was accepted that the party is an offshoot of the Kurdish resistance organization operating inside Turkey, the PKK, and therefore it is banned.',
#  'Reading the books is depressing, since it is clear that the intensity of the challenges and the lack of a clear alternative to dealing with them shakes the intelligence.',
#  'Resources will be invested in the fields of irrigation in the Palestinian Authority: infrastructure projects, health, law, education, employment, and more.',
#  'Similarly, Egypt should avoid fraudulent actions that harm foreign investors, or the appearance of such actions, such as the recently reported cases of tax avoidance.',
#  'It would be better to check how this is done in other countries.',
#  'In this context, Iran and Syria remained the last line of defense of Russian interests in the Middle East.',
#  'This is another symptom of the same paradox, reflecting the fear of criticism from home, and also it reduces the ability to use the military power and thus achieve set goals and objectives.',
#  'The security, economic, civil and political burden that will then be placed on her will be extremely heavy.',
#  'The resumption of talks was possible after heavy pressure from the United States on Abbas to waive the three conditions he placed for the resumption of talks.',
#  'The fact that Turkey is one of two countries (along with Qatar) in the Middle East that publicly oppose Saudi Arabia and are pro-Kashoghi has led to a lot of sympathy in the Arab public.',
#  'Its weakness at the moment is playing into the hands of Iran, which wants to appear as if it has influence over what is happening on the island.',
#  'These factors closely monitor all the expressions and "body language" of the leaders of the parties in order to prevent them from moving in the direction of the arrangement.',
#  'Check for example whether a user with a male profile picture writes in female language?',
#  'First, with the drafting of the original initiative  the Arab League.',
#  'It was only during the period following the Six-Day War that most, if not all, American Jews became supportive of Israel.',
#  'It should be assumed that the proportion of Arab judges in Israel, 8.4% in 2019, and the tenure of only one Arab judge out of 15 in the Supreme Court, is not satisfactory.',
#  'This year it will be opened on October 16th, this is the 20th time since the foundation of the party in 1921.',
#  'The economic situation, unemployment and lack of electricity and clean water are the main catalyst and driver behind the protest.',
#  'Borders between Israel and the future Palestinian state can only be determined by agreement between the two parties.',
#  'As for the consequences of the Nationality Law and the aforementioned processes: at the internal level, it seems that it is still too early to rationalize Israeli democracy.',
#  'If the canal goes on the road, he will be able to claim that he managed to do what various sultans and prime ministers in the past before him only dreamed of.',
#  'The outline does not address the question of Palestinian refugees, and yet it prevents their return to the territory of Israel in the future.',
#  'In addition, the points of dispute between Ankara and Athens also concern issues of economic importance, such as the exclusive economic watershed.',
#  "The agreement, brokered by the previous Trump administration, was accompanied by Washington's controversial decision to officially recognize Morocco's sovereignty over the Western Sahara.",
#  'Therefore, most programs at the national level, ranging from research and development to operational evaluations, need to be integrated and coordinated.',
#  'Achieving the agreement will also be seen as a political achievement for the outgoing US president, George Bush.',
#  'Some focused on the serious violation of privacy and argued that it goes beyond what is necessary.',
#  'He promised "to call hate by its name, whatever its source, and to defend it  always".',
#  "China's interest in the security of shipping lanes focuses on the necessary water crossings, such as the Taiwan Strait, Malacca, Hormuz and Suez.",
#  'Amos Yedlin in the role of Prime Minister, TPL (MIL.)',
#  'It is appropriate that the state does not indiscriminately initiate facilitations in payment for the contractual obligations of businesses in the business sector (rents, payments to banks and suppliers and the like).',
#  'As long as these challenges are not addressed, it will not be possible to move forward.',
#  'However, it remains to be seen that the political class attaches great importance to the appointment to this position.',
#  'Second, similar to the Jewish diaspora, Israel should also publicly adopt the report and strive to insert it into the local and international public discourse.',
#  'But it is likely that this procedure will not interest Tehran, if it decides to launch a bomb.',
#  "Mashrouket's solution is based on the work of analysts, who verify information appearing in the media.",
#  'Obama gives the impression that he wants to demonstrate both softness and toughness towards Iran, but such an approach is unlikely to succeed.',
#  'He also established contact with a Hezbollah man for the purpose of drug trafficking, and gave him information about what was done in Israel during the Second Lebanon War.',
#  'In recent weeks, there has been a renewed increase in efforts at political and civilian repression by the Iranian governments.',
#  'However, it seems that the Iranian emphasis in this project is actually on the ability to launch satellites.',
#  'Accepting the citizenship of another country, such as Jordan for example, does not affect the refugee status either.',
#  'However, the plaintiff went into great detail, which was not mandatory at this point and from which it is clear that the Palestinian narrative regarding the conflict has been completely adopted.',
#  'Chapter 7: Possible impacts on the international arena',
#  'As is well known, the understanding on the freeze for ten months was agreed with Ambassador Mitchell and the president himself.',
#  'Since the beginning of the upheaval in the Arab world, the monarchs have condemned any attempt, real or imagined, by civil society to challenge the existing political structures.',
#  'This case, then, illustrates the importance of active participation in the judicial procedures of international courts.',
#  "Israel's ability to carry out a repeated attack with a different approach is more limited.",
#  'Among the additional findings of the study:',
#  'Such a reference absorbs an archaic theme whose roots are planted in the first years after the foundation of the state.',
#  'Change groups: Shias, women and young intellectuals',
#  'This decision constitutes a deviation, although not for the first time, from a long-standing policy not to supply weapons to areas of tension (for example, the supply of weapons to Israel).',
#  'This, as an alternative to the militant friction led by Hezbollah against Israel, which may escalate and cause further humanitarian damage in Lebanon.',
#  'For example: Israel lags very far behind in the proportion of researchers in the epidemiological tests compared to the situation in developed countries.',
#  'Two of them actually realized their intentions and became the first American suicide bombers abroad.',
#  'Since the survey was conducted by the Palestinian HLC, we are not afraid of avoiding reporting on employment in Israel without an Israeli permit.',
#  'The ports of Haifa and Ashdod currently handle about 3 million TEU per year, each accounting for about 50 percent of the container market entering Israel.',
#  'In many cases, the patients themselves publish the list of places where they stayed.',
#  'In 13 settlements, the Hadassah lost the position of head of the authority.',
#  "And if Israel's leaders are unable to do so, they must be prepared for the continued alienation of the Jews of the United States from them.",
#  'When military regimes go through democratization processes, their countries allocate an average of 13% of their primary power structure to establish one or several parallel forces.',
#  "As recommended achievements for the prime minister's visit to China, it is proposed:",
#  '(It is not clear whether the Russian proposal also concerns the placement of Iranian weapons systems in Syria, mainly surface-to-surface missiles and air defense systems).',
#  'Considering the positive and negative aspects, a clear picture is painted in favor of moving the American embassy to Jerusalem.',
#  'However, the assumption that the two peoples can live in one fold is contrary to common sense, after decades of bloody conflict.',
#  'These organizations are supported by social, economic, political and religious institutions, and operate from the heart of the densely populated civil space, within failed states or entities.',
#  'A generic model for the mission team structure',
#  'Iran froze its military nuclear program, which involved secret facilities for the conversion and enrichment of uranium, and experiments to turn fissile material into weapons.',
#  'The project is funded by the European Union and supported by the European Investment Bank (EIB).',
#  'Therefore, some of them can be identified as being based on separate sovereign nation states, each of which has a unique identity.',
#  "Fourth, the EU's course reflects a cautious approach to the issue of responsibility and attitudes towards specific countries, apparently for political reasons.",
#  'The agreement could have a negative impact on the continuation of trade with countries outside the region, among them Israel, due to the economic priority for trade between the partnerships.',
#  'As with the court, one can criticise the excessive "justification" of the decision-making process.',
#  'Also, Huawei invested in the Elastifile company that deals with data storage.',
#  'The establishment of a "warning" system was recently completed, which is supposed to provide (with limits) short-term warning of earthquakes.',
#  'The arrival time of the laser beam for a target located at a distance of 10 km is only 30 millionths of a second.',
#  'Both sides expressed their displeasure with the contents of the report.',
#  'The political arena and public opinion',
#  'Recognition of the State of Israel as a Jewish state means giving up the right of return',
#  'It should be noted that a few weeks ago the political and security cabinet decided to adopt the defense plan for 2019-2030, which includes a special budget for the strengthening of buildings in risk areas.',
#  'Article on changing attitude in Iran towards the Taliban, July 2021',
#  'The annexation moves could draw a very long border for the defense, remove the possibility of future negotiations and may also lead to increased international recognition of the Palestinian demands.',
#  'Indeed, the relationship with Israel carries with it diverse advantages for the UAE.',
#  'In the 2014 European Parliament elections, these two parties won 412 of the total seats.',
#  'Therefore, a publicity in the relationship with the United States and behavior that will be perceived as problematic at the international level may expose Israel to operational decisions against it.',
#  'Greece cannot and will not want to be a substitute and Israel will have difficulty penetrating the Greek market controlled by American and European industries in this area.',
#  'The UN Security Council is authorized to deal with issues where there is a threat to security and peace in the international arena.',
#  'Maturing geo-strategic processes in the Eastern Mediterranean',
#  "Many in the West were indeed quick to tie crowns to bin Salman's head - some claiming that he symbolizes in his vision and attributes Kamal Ataturk, the father of modern Turkey.",
#  'These changes are only effective for those states that have ratified the amendment individually...',
#  "Thoughts on deterrence: Lessons from Israel's wars since 1967",
#  'Among others, the President of the Palestinian Authority, Mahmoud Abbas, visited Turkey a few days after the announcement of the normalization between Turkey and Israel.',
#  'The appointed Minister of Interior is appointed Ahmed Wahidi, former commander of the Quds Force of the Revolutionary Guards (1997-1988), and Minister of Defense in the Ahmedinejad government.',
#  'This is an agreement that expresses the need for both powers to advance their goals, even though the current one is only limited.',
#  'Although these countries have increased oil reserves in recent years, over time these reserves will dwindle and accelerate oil sales.',
#  'Brick was a brigade commander and a brigade commander in the armored corps, a commander of the bride and commander of the military colleges.',
#  'Allegedly, the events on the distant continent do not concern Israel.',
#  'The Jew, perceived as the bearer of the essence of evil in its various forms, was therefore seen by Nazi eyes as the embodiment of the forces of darkness" (p.',
#  'This is a wide-ranging budgetary and operational challenge.',
#  'Apps and technologies whose recipient is the violent man and whose purpose is to prevent him from repeating his actions.',
#  'The League examines every report and, if possible, compares it with an independent investigation.',
#  "Contrary to the rhetoric that emphasizes political support, China's economic assistance to the Palestinians is minimal.",
#  '[23] Ayadi and Gad; Interview with Prof. Ilhan Khat, former Deputy Secretary General of the UfM for Education and Research, 13.10.2020.',
#  'They also hold house circles known as "divaniah" and raise funds to send to the battalions in the field.',
#  'In addition, there is concern about the new wind blowing in Washington towards Russia and its consequences for the future of Syria.',
#  'Following Operation Pillar of Cloud and the events in the Arab world, Hamas is also under pressure from the local population  a restraining pressure that the organization cannot ignore.',
#  'The signposted approach here regarding the Arab public is in the possession of a warning signal.',
#  'The second aspect concerns the weakness of the defense.',
#  'Third, since the joining of Ansar Beit Al-Maqdiss to ISIS, Wilayat Sini holds, in practice, in Sinai territory.',
#  'For Saudi Arabia, the first priority is American protection against Iranian aggression.',
#  'Keywords: Salafi, Salafi-Jihadi, "Islamic State", Israel, Natham Abu Salim, Christians, Jews, World Jihad, "Al-Qaeda", Terrorism, Sharia.',
#  'The European Union intends to eliminate greenhouse gas emissions by 2050, to disconnect economic growth from the use of resources and "leave no one behind".',
#  'Small in dimensions, it can be worn on the garment.',
#  'In this context, the preservation of the peace agreements with Egypt and Jordan, and cooperation with Saudi Arabia and the Gulf countries.',
#  'Thus, the process of renewing ties between Iran and all the Gulf countries will be completed.',
#  "In the Iranian context, China is expressing its dissatisfaction, both with the deadlock on the nuclear agreement and with its damage to its partners and China's interest in the Gulf.",
#  'Food prices have risen by 200 percent, and there has been an increase in the number of suicides on an economic background.',
#  'In an attempt to soften the negative trend, Israel agreed with the PA on a transfer of funds that would allow it to manage 2019 in relative peace.',
#  'There is broad agreement among researchers and observers that the region is in a deep crisis, in a process with historical implications and a turbulent battle for its image.',
#  'The policy of the United States under the administration of President Donald Trump has experienced significant changes over the past year.',
#  'But a twin can also take the form of a package deal.',
#  'President Hassan Rouhani, for his part, noted that Iran will agree to a dialogue if the United States respects the agreement and sanctions are lifted.',
#  'The women who participated in the suicide bombings in Nigeria were sent by the organization.',
#  'Perhaps this fact should not be surprising given the fact that even among African Americans, satisfaction rates with the president have dropped from 90 to 80.',
#  'Among the Democratic Party and the president himself, there is a deep dislike of the theocratic Saudi West and the de facto ruler, the heir to the throne, bin Salman in particular.',
#  'Looking back, it seems that in the event itself the intelligence community on its various arms managed to join efforts and act with a high level of coordination.',
#  'Russia and China, this time joined by Germany, are not ready to punish Iran with a third round of sanctions until it becomes clear where the process is leading.',
#  'Khan noted that the investigation revealed that alleged crimes were also committed by a general in the Russian army, but he died.',
#  'In the case of Ukraine, Russia is seeking to thwart the threat posed by NATO\'s "spreading east".',
# ...
#  'In Syria, it lost about 30 percent of its territory, including areas in the northwest of the Al-Araqa province, Manabge, Al-Bab and Damur.',
#  'Many food factories, which need the status of an essential factory to allow workers to come to work, are still waiting to receive government approval.',
#  'This new situation allows Israel to reach more stable understandings with Hamas if it wanted them.',
#  'Such is the case, for example, with the civil nuclear reactor in Bushehr that Russia built in Iran.',
#  'The soldiers recruited in accordance with the additional shortening are to be released according to the law starting from the end of 2022.',
#  'Hadi, who was the deputy of Ali Abdullah Salah, the former president of Yemen, served since 2012 and was perceived as an obstacle to order.',
#  'The 2020 elections are therefore also an opportunity for the growth of a new American leadership for the democratic-liberal idea.',
#  'The reason for this is obvious.',
#  "These measures include a series of economic agreements that will help the Assad regime rebuild the destruction it has wrought on Syria and ensure Iran's place in the reconstruction process.",
#  'His associates are also among the members of the new organization who share his vision.',
#  'The article offers an analytical framework based on the "Talin Manual" for schematizing war and crisis zones.',
#  'Iranians have opened schools, where the language of instruction is Persian, and they offer scholarships to students, including for studying in Iran.',
#  'Everything will be ready for that day in the not-too-distant future.',
#  'For Israel, the possibility of instability in North Africa poses security challenges, but also potential opportunities.',
#  'The downing of the plane was perceived in Russia as a serious blow to its image at the international level, at the crisis level in Syria, as well as at the domestic Russian level.',
#  'The only achievement that Nasrallah could present in this context was the additional burden placed on the IDF following the ongoing tensions on the Lebanese border, which led to the strengthening of its forces.',
#  'However, there is still no comprehensive vision of the initiative, which will allow to reach agreement on the various efforts required to achieve its goals and create synergies between them.',
#  'With the outbreak of the coronavirus crisis, Egypt suspended tourism, including in popular accommodation destinations in southern Sinai.',
#  'At the heart of the matter is a basic asymmetry between a local authority in Israel and municipal and provincial authorities in China, such as the branches of the central government in China.',
#  'Already now one can see the clash between the changes in the perception of the Turkish threat and the perception of the threat of most NATO members.',
#  'Building the power to realize "determination" and "victory" - the continental maneuver',
#  'The continuation of the crisis beyond the next two to three months could cause negative annual growth.',
#  'As a result, the Egyptian regime disconnected the Internet and partially the cellular communications.',
#  "Violence was indeed included in the Arab minority's resistance strategies, but it was the exception contrary to popular belief.",
#  'This recognition led to the fact that, for the first time, it was in the common interest of both countries to clarify intentions - which served as a basis for their agreement to implement the initial step.',
#  'This will have a direct impact on tourism, the national economy, the demand for refrigeration energy as well as on military operations.',
#  'In this reality, formal and informal interfaces between society and the army were created and a rapprochement between the military and civilian system began.',
#  'Second, if the nuclear agreement is renewed, Iran will be able to return to the global oil market, where Russia is a significant player in its price stabilization through "OPEC Plus".',
#  "The words of the Iranian commanders stem primarily from Iran's basic ambition for hegemony in the Middle East, and in some respects also beyond it.",
#  'In addition, a well-known secret is that the service in the reserves is in fact voluntary (although it is held by law).',
#  'China also unveiled the DF-ZF missile, which since 2014 has conducted at least seven test flights, most of which were deemed successful.',
#  "The JVP report concluded that it confirmed the activists' suspicions that Israel is responsible for racial discrimination in the United States (JVP, 2017).",
#  'The record of the massacres that Israel has initiated is involved.',
#  'However, harsh criticism was presented about the killing of women and children by Israel.',
#  'Trump himself did not address the issue of regime change activities in Iran.',
#  'Are we living in a post-truth era?',
#  'The Egyptian regime promoted wide-ranging plans for the development of northern and southern Sinai (Charts 1 and 2).',
#  'Entity names: Entity names appear, disappear and change in almost every operation.',
#  'Graph 2 presents the distribution of Israeli exports to China in a branch section, according to the average for the years 2015-2018 and the data of the Export Institute.',
#  'It can be assessed that those who think so do not understand the meaning of a professional army, however, this statement is important for understanding the ethics of Israeli society.',
#  'Below are the main references, and their implications for Israel and its national security.',
#  'At first, Khashoggi expressed complete support for the young heir to the throne, and even accepted his policy against Iran and the vision 2030 he set for the kingdom.',
#  'Although the Assad regime remains committed to Iran and does not intend to break away from it, even in exchange for rejoining the Arab world and receiving vital economic assistance.',
#  'The Gulf Fund established by Saudi Arabia, the UAE, Qatar, and Kuwait, decided to provide $5 billion over 5 years for development projects.',
#  'On March 3, Iranian President Mahmoud Ahmadinejad paid his first official visit to Saudi Arabia.',
#  "In recent months, Wagner's group owners have become an increasingly political figure in Russia.",
#  'It began in January 2011 under the influence of the events of the "Arab Spring" and as a response to the already difficult situation in Yemen.',
#  'Fighting between the Ukrainian army and the Russian army in the suburbs of Kiev, March 10, 2022',
#  'The meaning of the arrangement is a positive change in relations between Russia and the West.',
#  'In many cases, such a political structure is used to glorify the uniqueness of the "enclaved" according to their sectoral needs.',
#  'Hostility against Jews in the street',
#  'Heatwaves in the Gaza Strip, as in Israel, are expected to be longer, more intense and frequent and will also occur in months when they have so far been considered rare.',
#  'Israel is monitoring the crisis caused by the launch of a long-range missile by North Korea and examining its consequences, especially with regard to the Iranian nuclear program.',
#  'In recent months, many participatory demonstrations have been held demanding the transfer of power from military commanders to civilian leadership.',
#  'The important question at hand is, what will be the Iranian reaction?',
#  'In conclusion, it is recommended that Israel not automatically oppose any Egyptian-Iranian normalization, but strive to ensure that its capabilities will be in line with Israeli interests.',
#  'Champions Discussion  Over the past fifty years',
#  'The second wave of the coronavirus pandemic also affected the Palestinian population and economy.',
#  'For nearly 70 years, Republican and Democratic governments alike have expressed a commitment to maintaining the security of the kingdom.',
#  "In any case, it is doubtful whether Biden's desire to restore stability and foresight to U.S.-Russia relations will be realized due to Putin's conflicting interest.",
#  'However, it seems that the combination of factors makes it necessary to maneuver in the face of an overabundance of risks, the likelihood of which will increase as long as the Israeli operation continues.',
#  'More importantly, it has been proven time and again in the past that the influence of the "Arab street" of its governments is limited.',
#  'It is likely that China and Russia will be less upset by an Israeli attack than by an American one, and perhaps more willing to participate in preventing a subsequent escalation.',
#  'If you support Russia, you will risk its important relations with Europe and the United States as well as its position as a responsible power that promotes peace in the world.',
#  'If this happens, the American military option will also return and come up on the table, thus providing backup for the Israeli option.',
#  'In May 2009, Huntsman headed a trade delegation to Israel, which was intended to expand the "strategic relations" between Utah and Israel.',
#  'The results of the presidential election held in Turkey on May 14 were a major victory for the incumbent president, Recep Tayyip Erdogan, and a major disappointment for the opposition.',
#  'This was also the leading message in the report of the Commission of Light, established in the aftermath of the severe riots of October 2000.',
#  'The most worrying operational problem, which was also revealed in the current exercise, despite the talk of improvement, is related to the issue of intersystemic coordination.',
#  "At this point, Prime Minister Netanyahu's envoy, who was sent to Washington to discuss this issue with the government, was unable to reach an agreement with the American side.",
#  'Iran is working to develop and implement a strategy for action in cyberspace.',
#  'Calls in the format "conservatives, reformists, the story is over for all of you" indicate a loss of confidence on the part of the public towards both main political camps alike.',
#  'This perception did not provide a sufficient knowledge infrastructure for a broad and integrated war, such as in Lebanon.',
#  'Furthermore, it is apparent that at least sections of the Iranian public are ready to be satisfied  at least in the short term with the improvement of the economic situation.',
#  'I want to thank everyone who worked on the program, and the entire staff of the institute, who do a good job throughout the year.',
#  'The balance  Distribution of Pike News from 2013.',
#  'If between 2012 and 2016 the export of U.S. goods to the region amounted to 47 percent of total U.S. exports, between 2017 and 2021 the volume decreased to 43 percent.',
#  'Hillary Clinton did win technically, but it was far from the prominent lead she enjoyed just a few weeks earlier.',
#  'Iran is the fifth country in the world, and the first in the Middle East, in the number of deaths due to the coronavirus pandemic.',
#  'One of the problems stems from the fact that there is confusion between the terms compensation, reward and salary, which have a meaning beyond the definition itself.',
#  'INSS video: What are the interests involved in Israel-Turkey relations?',
#  'The RCEP agreement will enter into force after being ratified by all partner countries - a process expected to take two years.',
#  'In recent years, the attempts of foreign countries to influence the democratic processes in their rival countries have multiplied.',
#  'Concretely, the Chinese have in the past linked cooperation with the United States on the Iranian issue to easing American policy towards China on the Taiwan issue.',
#  "Any other policy could lead to a crisis in relations between the countries and has serious consequences for Israel's strategic environment.",
#  'Employment security is the main economic challenge  It is essential to use the crisis to boost the labor market and increase fertility.',
#  'Notable among the victims is Egypt, due to the decrease in traffic in the Suez Canal as a result of the reduction in international trade and tourism.',
#  'The chairman of the Central Election Commission will determine the methods of publication.',
#  'To this end, the government intends to lower barriers and promote competition in the market.',
#  "This is in the face of increased internal criticism for his role in Lebanon's economic and political crisis and especially ahead of the elections due to be held in the country on May 15.",
#  'However, it is doubtful whether the current American administration will be as "generous" as before in this regard.',
#  'A trend is developing that indicates the preference of the reduced framework  ethnic, tribal, communal, family  over the state one.',
#  'On the regional level: China and the Middle East',
#  'The author deals with examining those issues that are friction potential.',
#  'As for the first barrier, it is possible to point out relevant change trends.',
#  'The Western bloc is in retreat both in the Middle East and in the whole world and in the emerging situation that Islam is expected to prevail over the West.',
#  'Reducing morbidity is essential to achieving the goal of "flattening the curve", but it is expected that with the release of the restrictions, morbidity will return and increase.',
#  'It is no surprise that Hamas, which is preparing itself these days for the next conflict with Israel, is investing a concentrated effort in digging tunnels.',
#  "It is likely that the statement is also intended to appease Trump's evangelical support base ahead of the election year in the United States and to assist Netanyahu in the Israeli political arena.",
#  'Articles recently published in Israel and around the world raised doubts regarding the number of rockets fired at "Iron Dome" during Operation "Pillar of Cloud".',
#  'Parliamentary and judicial oversight of the government',
#  'The administration of President Biden, although he was not their biological father, adopted the "Abrahamic Agreements".',
#  'What stands out in this case is precisely the difference in the Russian approach to terrorism at home, compared to its attitude to radical Islamic elements abroad.',
#  'In conclusion, Israel agreed in 2000 to the conditions demanded by the UN.',
#  "The Iranian proposal came in response to requests from the P5+1 countries to hold talks on the nuclear issue, but it was missing a key element: some reference to Iran's nuclear program.",
#  'Relations between the cities, encouraged by the Chinese embassy in Israel, included exchanges of delegations and female secretaries on business, economic and cultural issues.',
#  'Among other things, the power vacuum is reflected in the preference of the security mechanisms to avoid a determined action against the armed militias.',
#  'And apparently, even on "soft" issues, such as adopting a common currency, it is difficult for countries to cooperate.',
#  'Federal Standards in Education',
#  'In August 2010 it was reported that the Ministry of Defense decided to purchase 20 F-35A aircraft.',
#  'In the Cold War era in its previous incarnation, China and Russia were not always on the same side of the conflict.',
#  'A number of intercept missiles were developed for the system.',
#  'There is no obvious answer to the first question.',
#  'At the same time, the threats from Iran increased while the Biden administration showed great interest in dialogue with Iran and in particular back to the nuclear agreement.',
#  'US President Joe Biden is expected to pay a visit to the Middle East on July 13-16, during which he will visit Israel and the Palestinian Authority.',
#  'For Jordan, the Palestinian question has existential significance because more than half of its population is of Palestinian origin.',
#  'US President Biden addresses the withdrawal from Afghanistan in a special speech, July 8, 2021',
#  'Such a setup has many components, but two of them are the most critical.',
#  'Indeed, most of the Arab volunteers between 1979 and 1992 came from Saudi Arabia.',
#  'First, the shortest pipeline route from the Israeli gas reserves to the Turkish coast should cross the exclusive economic zone of two countries - Lebanon and Syria.',
#  ...]

# %% [markdown]
# ## DOWNLOAD COMET MODEL

# %%
comet_model_path = download_model("Unbabel/wmt22-cometkiwi-da")
comet_model = load_from_checkpoint(comet_model_path)
# Out:
# Fetching 5 files:   0%|          | 0/5 [00:00<?, ?it/s]
# Lightning automatically upgraded your loaded checkpoint from v1.8.2 to v2.0.9. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint --file ../huggingface_cache/hub/models--Unbabel--wmt22-cometkiwi-da/snapshots/b3a8aea5a5fc22db68a554b92b3d96eb6ea75cc9/checkpoints/model.ckpt`
# Encoder model frozen.
# /anaconda/envs/translator/lib/python3.11/site-packages/pytorch_lightning/core/saving.py:165: UserWarning: Found keys that are not in the model state dict but in the checkpoint: ['encoder.model.embeddings.position_ids']
#   rank_zero_warn(

# %%
data = []
for index, row in df_samp.iterrows():
    data.append({
        'src': row['translation'][col_src],
        'mt': row['pred']  # TODO:HIGH:Restore: row[col_dst] row['translation']['en']  
    })
data
# Out:
# [{'src': 'תן לה כמה שעות, היא תהיה בסדר.',
#   'mt': "Give her a few hours, she'll be fine."},
#  {'src': 'הציונים ודאי מתכננים משהו גדול.',
#   'mt': 'The grades must be planning something big.'},
#  {'src': 'מי שלח אותך לכאן, המשמרות?', 'mt': 'Who sent you here, the shifts?'},
#  {'src': 'הדלת תקועה, אבל אל תדאג.',
#   'mt': "The door is stuck, but don't worry."},
#  {'src': 'אין לנו יכולת לדעת את זה.',
#   'mt': 'We have no ability to know that.'},
#  {'src': 'אז אנחנו פועלים מנתיב איי-301.',
#   'mt': 'So we are operating from route A-301.'},
#  {'src': 'לקחתם את הסחורה ונעלמתם.',
#   'mt': 'You took the goods and disappeared.'},
#  {'src': 'תוך כמה זמן הם פורקים?', 'mt': 'How soon do they unload?'},
#  {'src': 'טוב, זאת חמולה גדולה.', 'mt': "Well, that's a big load."},
#  {'src': 'אבל מעתה והלאה, אתה עובד בשבילי.',
#   'mt': 'But from now on, you work for me.'},
#  {'src': 'אני צריך ללכת לעשות משהו בשדה.',
#   'mt': 'I have to go do something in the field.'},
#  {'src': 'אבל אני לא רוצה שתמות לי ממחלה.',
#   'mt': "But I don't want you to die of disease."},
#  {'src': 'תנו לי לדבר איתה.', 'mt': 'let me talk to her'},
#  {'src': "זה התחיל בתור קומונה של אמנים, אבל עכשיו גרים כאן כל מיני חבר'ה.",
#   'mt': 'It started as an artist commune, but now all kinds of guys live here.'},
#  {'src': 'את חייבת את זה לאימא שלי.', 'mt': 'You owe it to my mother.'},
#  {'src': 'לא צריך לדבר על זה.', 'mt': 'No need to talk about it.'},
#  {'src': 'תשחרר את המשפחה שלי.', 'mt': 'Let my family go.'},
#  {'src': 'אנו מתחילים את העלייה למטוס, אנא גשו אל השער, תודה.',
#   'mt': 'We begin boarding, please proceed to the gate, thank you.'},
#  {'src': 'לכן זה היעד המרכזי שלנו.',
#   'mt': "That's why this is our main goal."},
#  {'src': 'אם אחד מאיתנו ידבר עם פרהאם, זה רק יבריח אותו.',
#   'mt': 'If one of us talks to Farham, it will only scare him away.'},
#  {'src': 'אולי לאחד העובדים שלי הייתה פגישה בחברת החשמל באותו ערב.',
#   'mt': 'Maybe one of my employees had a meeting at the electric company that evening.'},
#  {'src': 'עבדתי בחברת החשמל אבל עזבתי.',
#   'mt': 'I worked at the electric company but left.'},
#  {'src': 'רק תשאל אותו מה קורה.', 'mt': "Just ask him what's going on."},
#  {'src': 'הוא איש חשוב שאוהב להתמסטל.',
#   'mt': 'He is an important man who likes to get high.'},
#  {'src': '"אמר שצריך לעבוד "באופן חשאי.',
#   'mt': '"He said you should work "secretly.'},
#  {'src': 'שירה: תקשיב מה ראיתי בשירותים -.',
#   'mt': 'SONG: Listen to what I saw in the bathroom.'},
#  {'src': 'האם זה מר מסעוד טבריזי?', 'mt': 'Is this Mr. Massud Tabrizi?'},
#  {'src': 'איך עשיתם את זה?', 'mt': 'how did you do it'},
#  {'src': 'הם מצאו אותי בבית של חברה, שהיתי אצלה.',
#   'mt': "They found me at a friend's house, where I was staying."},
#  {'src': 'אבל זה לא מה שאני יודע.', 'mt': "But that's not what I know."},
#  {'src': 'אולי יש לך אורחת בבית?', 'mt': 'Maybe you have a guest at home?'},
#  {'src': 'אבל אני לא רוצה שתשכחי אותי.',
#   'mt': "But I don't want you to forget me."},
#  {'src': 'ביום שהם עזבו, נשבעת לי שתנתקי איתם כל קשר לצמיתות.',
#   'mt': 'The day they left, you swear to me that you will sever all contact with them permanently.'},
#  {'src': 'אתה חושב שהוא יעשה את זה?', 'mt': 'Do you think he will do it?'},
#  {'src': 'אומרים שאתה עובד עם הישראלים, שהם אלה ששילמו על הניתוח של גברת נאהיד.',
#   'mt': "They say you work with the Israelis, who are the ones who paid for Ms. Nahid's surgery."},
#  {'src': 'בשם האל, נעשה ונצליח.',
#   'mt': "In God's name, we will and we will succeed."},
#  {'src': 'אני לא במצב לעלות על מטוס עכשיו.',
#   'mt': "I'm not in a position to get on a plane right now."},
#  {'src': 'היה לי יום ממש ארוך, אז.', 'mt': 'I had a really long day, then.'},
#  {'src': 'שאתה לא רוצה שהילדים שלך יגדלו במדינה כזאת.',
#   'mt': "that you don't want your children to grow up in a country like this."},
#  {'src': 'דיברתי עם נהג המונית שאסף אותה.',
#   'mt': 'I spoke to the taxi driver who picked her up.'},
#  {'src': 'אני בכלל לא בטוחה שזו היא, כי.',
#   'mt': "I'm not even sure it's her, because"},
#  {'src': 'הוא לא יצא מכאן.', 'mt': "He didn't get out of here."},
#  {'src': 'אז אתה יודע מה לעשות?', 'mt': 'So you know what to do?'},
#  {'src': 'יש כאן מסיבות, הופעות חיות.',
#   'mt': 'There are parties here, live performances.'},
#  {'src': 'הפעולה הערב כוללת סריקה של צירי הגישה הסופיים אל היעד, והטמנת אמצעים טכנולוגיים לקראת הנחת מטעני נפץ מחר.',
#   'mt': 'The operation tonight includes scanning the final access points to the target, and installing technological measures for the landing of explosive devices tomorrow.'},
#  {'src': 'הוא ידע יותר מדי, תמר.', 'mt': 'He knew too much, Tamar.'},
#  {'src': 'אצא עוד מעט ואחזור לקראת הערב כדי לקחת את הדברים שלי.',
#   'mt': "I'll leave soon and come back for the evening to get my things."},
#  {'src': 'הסוכנת שלי מאוד אמינה.', 'mt': 'My agent is very reliable.'},
#  {'src': 'הרשיעו אותו במעילה בכספים שקשורים בנפט.',
#   'mt': 'He was convicted in absentia of oil-related finances.'},
#  {'src': 'שחררתי אותו כדי לראות אם הוא יעשה איזו טעות.',
#   'mt': 'I let him go to see if he made a mistake.'},
#  {'src': 'בכל מקרה, המטוסים המריאו.', 'mt': 'Anyway, the planes took off.'},
#  {'src': 'עכשיו אני מבינה למה.', 'mt': 'Now I understand why.'},
#  {'src': 'תרצה להזמין טיסה אחרת להיום, אדוני?',
#   'mt': 'Would you like to book another flight today, sir?'},
#  {'src': 'שם משתמש -: - :סיסמה - הכניסה אושרה - מוחסן, גופה!',
#   'mt': 'User name -: - :Password - Entry approved - Stored, corpse!'},
#  {'src': 'את יודעת, זה בסיס צבאי ישן.',
#   'mt': "You know, it's an old military base."},
#  {'src': 'לא, זה שום דבר.', 'mt': "No, it's nothing."},
#  {'src': 'גם אני לא יודע.', 'mt': "I don't know either."},
#  {'src': 'כבר הגענו עד לכאן, זה הזמן לעשות את זה.',
#   'mt': "We've already come this far, it's time to do it."},
#  {'src': 'אני רוצה לדווח לראש הממשלה שהמטוסים יכולים לבצע את המשימה שלהם הלילה בשקט, שיש לטייסים מי ששומר עליהם.',
#   'mt': 'I want to report to the Prime Minister that the planes can carry out their mission tonight quietly, that the pilots have someone watching over them.'},
#  {'src': 'לא אמרת שיושבים לאכול עכשיו?',
#   'mt': "Didn't you say they are sitting down to eat now?"},
#  {'src': 'אוקיי, עוד 20 דקות תמצאי דרך לרדת למטה בלי שמילאד ירגיש.',
#   'mt': "Okay, in 20 minutes you'll find a way to go down without Milad noticing."},
#  {'src': 'אני יכול ללכת לשירותים?', 'mt': 'can i go to the bathroom'},
#  {'src': 'הוא איים על החיים שלך.', 'mt': 'He threatened your life.'},
#  {'src': 'תסתכל על אורות העיר.', 'mt': 'Look at the city lights.'},
#  {'src': '-נעלו עליי, מבצע תמרון.', 'mt': '- Locked on me, maneuvering.'},
#  {'src': 'אז דמעות התנין שלך היו רק בשביל הבחורה?',
#   'mt': 'So your alligator tears were just for the girl?'},
#  {'src': 'כך הרבה יותר טוב.', 'mt': "That's much better."},
#  {'src': 'אולי לאחד הבחורים יש מפתח.',
#   'mt': 'Maybe one of the guys has a key.'},
#  {'src': 'אני לא מהמוסד או משהו, סתם טסתי להודו.',
#   'mt': "I'm not from the Mossad or anything, I just flew to India."},
#  {'src': 'סתם, קארים והשטויות שלו.', 'mt': 'Just, Karim and his nonsense.'},
#  {'src': 'רק רציתי להרגיש את הגוף שלך.',
#   'mt': 'I just wanted to feel your body.'},
#  {'src': 'את ודאי הבת של ארזו.', 'mt': "You must be Erzo's daughter."},
#  {'src': 'כשהוא מחליט משהו, אין עם מי לדבר.',
#   'mt': 'When he decides something, there is no one to talk to.'},
#  {'src': 'אני אוהב את המולדת שלי יותר ממה שנדמה לך.',
#   'mt': 'I love my homeland more than you think.'},
#  {'src': 'אתה יכול להשאיר את הפרטים שלך ונתקשר אליך.',
#   'mt': 'You can leave your details and we will call you.'},
#  {'src': '- אבתסאם עבדאללה איברהים בדראן - קומי.',
#   'mt': '- Abtsam Abdullah Ibrahim in Dran - Get up.'},
#  {'src': 'אוציא להורג את מרדכי.', 'mt': 'I will execute Mordecai.'},
#  {'src': 'בגלל זה יצרתי קשר איתך.', 'mt': "That's why I contacted you."},
#  {'src': 'הבת שלי לא יודעת מכלום.', 'mt': 'My daughter knows nothing.'},
#  {'src': 'צריך לעקוף את זה - מה אתה כותב שם?',
#   'mt': 'You have to bypass it - what do you write there?'},
#  {'src': 'הוא היה מנהל בנק.', 'mt': 'He was a bank manager.'},
#  {'src': "זאת ז'ילה גורבניפאר האמיתית.",
#   'mt': 'This is the real Zilla Gorbanipar.'},
#  {'src': "תשלח לי דוח מפורט ואת התיק תעביר למח' ביטחון המדינה.",
#   'mt': 'Send me a detailed report and transfer the case to the Ministry of State Security.'},
#  {'src': 'עשיתי את זה רק בשביל הבת שלי.',
#   'mt': 'I only did it for my daughter.'},
#  {'src': 'האנשים הכי טובים שלנו על זה.', 'mt': 'Our best people are on it.'},
#  {'src': 'טוב, הוא טיפל בנייד שלנו, שיבש את הסיגנל, מחובר דרך מרכזיה מרוחקת באזור שטוקהולם.',
#   'mt': 'Well, he took care of our mobile, corrupted the signal, connected through a remote hub in the Stockholm area.'},
#  {'src': 'אז עדיף שאני אגיד להם שאתה לא יכול לעשות את זה?',
#   'mt': "So it's better if I tell them you can't do it?"},
#  {'src': 'לא, אבל אנחנו מצמצמים את האפשרויות.',
#   'mt': 'No, but we are narrowing the options.'},
#  {'src': 'למה הוא צעק עלייך?', 'mt': 'Why did he yell at you?'},
#  {'src': 'הוא יודע יותר מדי.', 'mt': 'He knows too much.'},
#  {'src': 'מה יש לחבר שלך?', 'mt': "What's wrong with your friend?"},
#  {'src': 'אנחנו צריכים שתמלא כמה הוראות.',
#   'mt': 'We need you to follow some instructions.'},
#  {'src': 'תחזרי הביתה עד מחר אחר הצהריים.',
#   'mt': 'Come home by tomorrow afternoon.'},
#  {'src': 'ושם הכרתי את בעלי.', 'mt': "And that's where I met my husband."},
#  {'src': '- המתחם הטכני אבאביל, טהרן - אחלה משחק.',
#   'mt': '- Ababil Technical Complex, Tehran - Great game.'},
#  {'src': 'הוא לא יציב נפשית.', 'mt': 'He is mentally unstable.'},
#  {'src': 'בעזרת השם, מחרתיים נתראה ונתחבק.',
#   'mt': "With God's help, the day after tomorrow we will see and hug."},
#  {'src': 'אסביר לך הכול כשניפגש, טוב?',
#   'mt': "I'll explain everything to you when we meet, okay?"},
#  {'src': 'אז אתה האחראי פה.', 'mt': 'So you are in charge here.'},
#  {'src': 'נתת לרגשות שלך לסכן את כל המבצע הזה.',
#   'mt': 'You let your feelings jeopardize this whole operation.'},
#  {'src': 'חודשים הסרטן אכל את הגוף היפה שלה.',
#   'mt': 'For months the cancer ate away at her beautiful body.'},
#  {'src': 'זה קשור לעבודה של בעלך.',
#   'mt': "It has to do with your husband's job."},
#  {'src': 'אני מקווה שאני לא מפריעה לך.',
#   'mt': "I hope I'm not bothering you."},
#  {'src': 'היית צריך לספור קודם.', 'mt': 'You should have counted first.'},
#  {'src': 'אני לא יכולה, אדוני השוטר.', 'mt': "I can't, Mr. policeman."},
#  {'src': 'ביקשו ממני להגיד לך שפעלת נכון ושאם תמשיך כך, נתראה בקרוב.',
#   'mt': 'They asked me to tell you that you did the right thing and that if you continue like this, we will see you soon.'},
#  {'src': 'אני בחרתי לעצום עין אחת.', 'mt': 'I chose to close my eyes.'},
#  {'src': 'כמעט ברמה של שפת אם, אבל גם שהיה לה קצת מבטא זר.',
#   'mt': 'Almost at the level of a native tongue, but she also had a bit of a foreign accent.'},
#  {'src': 'המשפחה שלי כבר בסכנה.', 'mt': 'My family is already in danger.'},
#  {'src': 'האנשים שמשרתים את השטן הגדול ואת השטן הקטן, את אמריקה ואת הציונים.',
#   'mt': 'The people who serve the big devil and the little devil, America and the Zionists.'},
#  {'src': '"ואיפה היא עכשיו, "תמר רביניאן?',
#   'mt': '"And where is she now, "Tamar Rabinian?'},
#  {'src': 'הלוואי שההורים שלי היו באים לבקר אותי.',
#   'mt': 'I wish my parents would come visit me.'},
#  {'src': 'אני אומרת לך את זה ברוגע.', 'mt': 'I tell you this calmly.'},
#  {'src': 'אז אנחנו חייבים את מילאד.', 'mt': 'So we owe Milad.'},
#  {'src': 'הייתי בטוחה שעצרו אותך.', 'mt': 'I was sure you were arrested.'},
#  {'src': 'סליחה, זה התארך קצת.', 'mt': 'Sorry, it went on a bit.'},
#  {'src': 'נאהיד, אשתי, הכריחה אותי להפסיק.',
#   'mt': 'Nahid, my wife, forced me to stop.'},
#  {'src': 'זה פחות צפוי, לא?', 'mt': "It's less predictable, isn't it?"},
#  {'src': 'ניתן להם לחשוב שאנחנו מחפשים אחר אזרחית איראנית.',
#   'mt': 'We will let them think that we are looking for an Iranian citizen.'},
#  {'src': 'אז ארזו סיפרה לך הכול.', 'mt': 'So Arzo told you everything.'},
#  {'src': 'היי, חכה, אל תיגע בזה, תפסיק.',
#   'mt': "Hey, wait, don't touch it, stop."},
#  {'src': 'אתמול בלילה היא עלתה על טיסה חזרה.',
#   'mt': 'Last night she boarded a return flight.'},
#  {'src': 'תשאל את מוחסן, הוא עבד שם.', 'mt': 'Ask Mohsen, he worked there.'},
#  {'src': "אני בבסיג' של הסטודנטים.", 'mt': "I'm in the student's bay."},
#  {'src': 'את יכולה לשים את בגדייך בסל, אכבס לך אותם.',
#   'mt': "You can put your clothes in the basket, I'll wash them for you."},
#  {'src': 'זו תחנת החשמל המשנית של טהרן.',
#   'mt': "This is Tehran's secondary power plant."},
#  {'src': 'זה סוג של עוף דורס.', 'mt': "It's a type of doris chicken."},
#  {'src': 'אנחנו צריכים שיגיעו יותר בנות!',
#   'mt': 'We need more girls to come!'},
#  {'src': 'כי אם זה המצב, זה הסוף.',
#   'mt': "Because if that's the case, it's the end."},
#  {'src': 'אין לי לאן ללכת.', 'mt': 'I have nowhere to go.'},
#  {'src': 'אז אני אומרת לך, אם משהו יקרה לו, זה יהיה באחריותך.',
#   'mt': "So I'm telling you, if anything happens to him, it will be your responsibility."},
#  {'src': 'מה שאני אומר לך נשאר בינינו.',
#   'mt': 'What I tell you stays between us.'},
#  {'src': 'אתה יודע מה העונש על דבר כזה.',
#   'mt': 'You know the penalty for such a thing.'},
#  {'src': 'המשטר הזה מחרבן על כל המדינה.',
#   'mt': 'This regime is shitting all over the country.'},
#  {'src': 'בשביל החיים שלך, ובשביל החיים של אשתך ושל הילדות שלך.',
#   'mt': 'For your life, and for the lives of your wife and children.'},
#  {'src': 'יש לך זכות מלאה לכעוס עליי.',
#   'mt': 'You have every right to be mad at me.'},
#  {'src': 'חמש שנים לא נגעתי בסיגריה.',
#   'mt': "I haven't touched a cigarette in five years."},
#  {'src': 'עכשיו תוציא את הסורק.', 'mt': 'Now take out the scanner.'},
#  {'src': 'הללי, תודיע למח"א שהמטוסים חשופים למכ"ם האיראני.',
#   'mt': 'Haley, inform the MIA that the planes are exposed to the Iranian radar.'},
#  {'src': 'רחוקים מהמדינה היקרה שלנו, חיים במדינה חדשה, אלה הדברים שהרגו אותה.',
#   'mt': 'Far from our dear country, living in a new country, these are the things that killed her.'},
#  {'src': 'אז למה את עוזבת?', 'mt': 'So why are you leaving?'},
#  {'src': 'נראה לך שאני יכולה לשבור מפרקת לבן אדם?',
#   'mt': "Do you think I can break a man's neck?"},
#  {'src': 'לא שמעת את ההודעה שלי?', 'mt': "Didn't you hear my message?"},
#  {'src': 'בצע ניתוק נעילה מטק"א.',
#   'mt': 'Perform a lockdown disconnection from TKA.'},
#  {'src': 'את חייבת להאמין לי.', 'mt': 'You have to believe me.'},
#  {'src': 'אין כסף, אין תעסוקה.', 'mt': 'No money, no employment.'},
#  {'src': 'האם ראית אותה במקרה?', 'mt': 'Have you seen her by chance?'},
#  {'src': 'פראז, אשתך מקבלת את הטיפול הרפואי הטוב ביותר שאפשר לקבל.',
#   'mt': 'Faraz, your wife is receiving the best medical care possible.'},
#  {'src': 'המטוס עוד לא נחת.', 'mt': 'The plane has not yet landed.'},
#  {'src': 'אני לא יודעת את כל זה, כי.', 'mt': "I don't know all that, because"},
#  {'src': 'אבל זה דורש אומץ, לא?', 'mt': "But it takes courage, doesn't it?"},
#  {'src': 'הסתובבנו בהרים פעם, עשינו טיול ולגמרי הלכנו לאיבוד, ו.',
#   'mt': 'We wandered in the mountains once, we took a trip and we totally got lost, and.'},
#  {'src': 'אבא שלי, סבא שלך.', 'mt': 'My father, your grandfather.'},
#  {'src': 'תגיד, מילאד אמר שהחברה שלו עבדה בחברת החשמל?',
#   'mt': 'Say, Milad said that his girlfriend worked at the electric company?'},
#  {'src': 'אני אגיד לך מה נראה לי.', 'mt': "I'll tell you what I think."},
#  {'src': 'היא נקלעה לשם בטעות.', 'mt': 'She got there by mistake.'},
#  {'src': 'רפורמיסטים, שמרנים, הסיפור נגמר!',
#   'mt': 'Reformists, conservatives, the story is over!'},
#  {'src': 'תדווח שוב על התקלה.', 'mt': 'Report the malfunction again.'},
#  {'src': 'מה זה המקום הזה?', 'mt': 'what is this place'},
#  {'src': 'מקומות שהוא לא היה אמור לגלוש אליהם.',
#   'mt': "Places he wasn't supposed to surf."},
#  {'src': 'מה עשית בשתי זירות הרצח הללו, באותו ערב, בהפרש של שעתיים?',
#   'mt': 'What were you doing at these two murder scenes, that night, two hours apart?'},
#  {'src': 'היא לא הלשינה על אף אחד.', 'mt': "She didn't snitch on anyone."},
#  {'src': 'מה קרה עם הדיילת-?', 'mt': 'What happened to the stewardess?'},
#  {'src': "שלום, מנוצ'הר, מה שלומך?", 'mt': 'Hello, Muncher, how are you?'},
#  {'src': 'הוא לא סתם מסומם.', 'mt': "He's not just drugged."},
#  {'src': 'התכוונו לשחרר אותה בימים הקרובים.',
#   'mt': 'We intended to release her in the next few days.'},
#  {'src': 'מה עם המשפחה שלך?', 'mt': 'What about your family?'},
#  {'src': 'כמה זמן אתה מכיר אותי?', 'mt': 'how long have you known me'},
#  {'src': 'נהיה אצלך בעוד שלוש דקות.',
#   'mt': "We'll be with you in three minutes."},
#  {'src': 'אביא אותן לכל מקום בעולם שתרצה לגור בו, אבל אתה מוכרח לעזוב את איראן עכשיו.',
#   'mt': 'I will bring them anywhere in the world you want to live, but you must leave Iran now.'},
#  {'src': 'סלח לי, אדוני, אבל אני מקווה שזה לא מה שאתה חושב עליי.',
#   'mt': "Forgive me, sir, but I hope that's not what you think of me."},
#  {'src': 'ד"ר טורבאתי למחלקת הילדים.',
#   'mt': 'Dr. Torbati to the pediatrics department.'},
#  {'src': 'התמונה הזאת, זה מה שהחמ"ל בארץ משדר.',
#   'mt': 'This picture is what the Hamas in Israel broadcasts.'},
#  {'src': 'היינו בקשר כמה חודשים, ואז הקשר גלש ל.',
#   'mt': 'We were in a relationship for a few months, and then the connection went haywire.'},
#  {'src': 'עובד ברשות השופטת בשם דאריוש.',
#   'mt': 'Works for the judiciary named Dariush.'},
#  {'src': 'אני מקווה שתחזור אלינו בקרוב.',
#   'mt': 'I hope you will come back to us soon.'},
#  {'src': 'עבדתי בחברת החשמל מאז שחזרנו מקטאר.',
#   'mt': "I've been working at the electric company since we got back from Qatar."},
#  {'src': 'והלך לה טוב, ללא ספק.', 'mt': 'And it went well for her, no doubt.'},
#  {'src': 'בדוק בכל התחנות במחוז.',
#   'mt': 'Check all the stations in the district.'},
#  {'src': 'אתה רוצה שאראה לך את בדיקת הרקע שעשו עליך?',
#   'mt': 'Do you want me to show you the background check they did on you?'},
#  {'src': 'הייתי מחשיך את כל העיר.', 'mt': 'I would darken the whole city.'},
#  {'src': 'חשבתי שאם תהיה הפסקת חשמל איפשהו.',
#   'mt': 'I thought if there was a power outage somewhere.'},
#  {'src': '- .עלי: תבדוק ברחוב איסתיקלאל 13 - יש אנשים בפנים.',
#   'mt': '- Ali: Check at 13 Istiqlal Street - there are people inside.'},
#  {'src': 'הקשיים שלה, הקשיים שלנו.',
#   'mt': 'Her difficulties, our difficulties.'},
#  {'src': 'עלייך להישאר ככה עד הטיסה.',
#   'mt': 'You have to stay like this until the flight.'},
#  {'src': 'הלכתי לטפל במה שביקשת.',
#   'mt': 'I went to take care of what you asked for.'},
#  {'src': 'שלוש, מבצע תמרון, שובר חזק.',
#   'mt': 'Three, maneuvering operation, strong breaker.'},
#  {'src': 'אם כך, לך תצית את עצמך.', 'mt': 'Then go set yourself on fire.'},
#  {'src': 'בואי נאכל לפני שפרהאם יגיע.',
#   'mt': "Let's eat before Ibrahim arrives."},
#  {'src': 'ואני עוזבת את איראן, אז.', 'mt': "And I'm leaving Iran, then."},
#  {'src': 'אני לא יודע, זה.', 'mt': "I don't know, it's"},
#  {'src': 'האימא מסתכלת עליהן ואומרת, "!הימנית" "?הוא אומר, "וואו, אמא, איך ידעת "!היא עונה, "כי אני כבר שונאת אותה זה טוב, נכון?',
#   'mt': 'The mother looks at them and says, "!right" "?He says, "Wow, mom, how did you know"! She replies, "Because I already hate her.'},
#  {'src': 'למה בכלל הבאת אותה?', 'mt': 'Why did you even bring her?'},
#  {'src': 'אלה אותם נוסעים שעלו בירדן?',
#   'mt': 'Are these the same passengers who boarded in Jordan?'},
#  {'src': 'טיסה מירדן נחתה אצלנו נחיתת אונס.',
#   'mt': 'A flight from Jordan made a forced landing at our place.'},
#  {'src': 'נראה כמו ציפור שחורה כלשהי.',
#   'mt': 'Looks like some kind of black bird.'},
#  {'src': 'אתה מתכוון לעלות על טיסה אחרת היום?',
#   'mt': 'Are you going to board another flight today?'},
#  {'src': 'זה הוא כיוון אותך לשם?', 'mt': 'Is that he who directed you there?'},
#  {'src': 'מאיפה את מכירה את מר מסעוד טבריזי?',
#   'mt': 'How do you know Mr. Massoud Tabrizi?'},
#  {'src': 'העיקר זה להיפטר מהם כמה שיותר מהר.',
#   'mt': 'The main thing is to get rid of them as quickly as possible.'},
#  {'src': 'אני רק ממלא פקודות.', 'mt': 'I just follow orders.'},
#  {'src': 'תבדקו את זה מיד.', 'mt': 'Check it immediately.'},
#  {'src': 'רוצה שאקח אותך לשם?', 'mt': 'Want me to take you there?'},
#  {'src': 'ומה לגבי הכסף שנתתי לך?',
#   'mt': 'And what about the money I gave you?'},
#  {'src': 'יש לך עם מה לעבוד.', 'mt': 'You have something to work with.'},
#  {'src': 'תבחן גם את קלטת האבטחה.', 'mt': 'Also check the security tape.'},
#  {'src': 'כל הדמויות והאירועים המוצגים בסדרה - - .הינם פיקטיביים לחלוטין כל דמיון לאירועים או אנשים אמיתיים -, - ,חיים או מתים - .הינו מקרי בהחלט - בוקר טוב.',
#   'mt': 'All the characters and events presented in the series - are completely fictitious - any resemblance to real events or people -, -, alive or dead - is absolutely accidental - good morning.'},
#  {'src': 'תשתה כוס מים, תירגע ואז תתקשר אליי.',
#   'mt': 'Drink a glass of water, relax and then call me.'},
#  {'src': 'אני מתפללת שתמצא מקום בלבך לסלוח לי ושתגיע.',
#   'mt': 'I pray you find a place in your heart to forgive me and come.'},
#  {'src': 'אדוני, האישה הזו מטרידה אותי.',
#   'mt': 'Sir, this woman is bothering me.'},
#  {'src': 'איפה למדת לבשל ככה?',
#   'mt': 'Where did you learn to cook like that?'},
#  {'src': 'יש לי שם משפחה, משפחת עזיזי.',
#   'mt': 'I have a last name, the Aziz family.'},
#  {'src': 'היא לא שקרנית, אבל שתתעסק בעניינים שלה.',
#   'mt': "She's not a liar, but she should mind her own business."},
#  {'src': 'מה קרה, חתיכת זונה?', 'mt': 'What happened, you whore?'},
#  {'src': 'זאת האזהרה האחרונה שלך.', 'mt': 'This is your last warning.'},
#  {'src': 'בוא, אני אלווה אותך החוצה.', 'mt': "Come on, I'll walk you out."},
#  {'src': 'אני לא יכול לסכן אותו.', 'mt': "I can't risk him."},
#  {'src': 'אני רוצה להנחית עליהם מכה שתוריד אותם על ארבע.',
#   'mt': 'I want to deal them a blow that will bring them down on all fours.'},
#  {'src': 'נולדתי כאן, אבל גדלתי בקטאר וחזרתי לכאן לפני שנתיים.',
#   'mt': 'I was born here, but I grew up in Qatar and moved back here two years ago.'},
#  {'src': 'למה אתה מתקשר אליי?', 'mt': 'why are you calling me'},
#  {'src': 'לך תחבק את המשפחה שלך.', 'mt': 'Go hug your family.'},
#  {'src': 'לא, אני לא חושבת.', 'mt': "No, I don't think so."},
#  {'src': 'אני נתתי לו עוד כמה מכות-.', 'mt': 'I gave him a few more blows.'},
#  {'src': 'כל פעם שהייתי מסתכלת עליו, הרגשתי שאני מסתכלת על אחד הבנים בשכונה.',
#   'mt': 'Every time I looked at him, I felt like I was looking at one of the boys in the neighborhood.'},
#  {'src': 'הסרטון שלך היה רק ההתחלה.',
#   'mt': 'Your video was just the beginning.'},
#  {'src': 'תשלח את הצוות שלך.', 'mt': 'Send your team.'},
#  {'src': 'מישהי מגיעה לכאן לעיתים קרובות?',
#   'mt': 'Does anyone come here often?'},
#  {'src': '- .הייתה שם קצינה מהבסיס שלי - ?יוני: תגידי, נפלת על השכל סופית - טוב.',
#   'mt': "- There was an officer from my base there. -?June: Say, you've gone completely insane - Good."},
#  {'src': 'החבר שלי נרצח מול העיניים שלי.',
#   'mt': 'My friend was murdered before my eyes.'},
#  {'src': 'תודה רבה על הכול.', 'mt': 'Thank you very much for everything.'},
#  {'src': '-כמה זמן עד שתהיה לנו שליטה על המכ"ם?',
#   'mt': 'How long until we have control of the radar?'},
#  {'src': 'לא תהיה לנו עוד הזדמנות.', 'mt': 'We will not have another chance.'},
#  {'src': 'מילאד, תפסיק לחשוב מהזין שלך-!',
#   'mt': 'Milad, stop thinking out of your dick!'},
#  {'src': 'מדוע עזבתם בכל זאת?', 'mt': 'Why did you leave anyway?'},
#  {'src': 'השם שלך הועבר לכל תחנות הגבול, וגם אם תצליח איכשהו לצאת, ברגע שהרגל שלך תדרוך מחוץ לאיראן, הביקור הראשון שלי יהיה בבית הזה.',
#   'mt': 'Your name has been transferred to all the border stations, and even if you somehow manage to get out, as soon as your foot steps outside Iran, my first visit will be to this house.'},
#  {'src': 'שהאל הטוב והחנון ישמור אותה.',
#   'mt': 'May the good and generous God keep her.'},
#  {'src': 'הנה, מאדאם כמאלי, הכרכרה שלך הגיעה.',
#   'mt': 'Here, Madam Kamli, your carriage has arrived.'},
#  {'src': 'אמרתי לך שהאפליקציה הזאת לא שווה כלום.',
#   'mt': 'I told you this app is worth nothing.'},
#  {'src': 'תסמוך עליי, ניסיתי כל דרך אחרת.',
#   'mt': "Trust me, I've tried every other way."},
#  {'src': 'אבטלה, עובדים שעדיין לא קיבלו משכורת, וסטודנטים שנמצאים בכלא.',
#   'mt': 'Unemployment, workers who have not yet been paid, and students who are in prison.'},
#  {'src': 'אתה בתפקיד בכיר במערכת המשפט.',
#   'mt': 'You are in a senior position in the justice system.'},
#  {'src': 'את יודעת איך להשתמש בזה?', 'mt': 'do you know how to use it'},
#  {'src': 'את באמת רוצה ללכת הביתה?', 'mt': 'do you really want to go home'},
#  {'src': 'הרגע שרפת לי עבודה של חודש, לעזאזל!',
#   'mt': "You just burned a month's worth of work for me, damn it!"},
#  {'src': 'נתתי לכן הזדמנות, זה נגמר בטוטאל לוס.',
#   'mt': 'I gave you a chance, it ended in total loss.'},
#  {'src': 'מאיפה את מכירה אותה?', 'mt': 'how do you know her'},
#  {'src': 'המקום מאויש 24/7, יש שם טכנאים.',
#   'mt': 'The place is manned 24/7, there are technicians there.'},
#  {'src': 'בכל מקרה אתם תהרגו אותי בעוד רגע, נכון?',
#   'mt': "Anyway you're going to kill me in a moment, aren't you?"},
#  {'src': 'כי אני לא עושה את זה עוד פעם.',
#   'mt': "Because I'm not doing it again."},
#  {'src': 'לא, היא ואבא שלי לא באמת התאקלמו שם.',
#   'mt': "No, she and my father didn't really get along there."},
#  {'src': 'אני והעבודה הארורה שלי.', 'mt': 'Me and my damn job.'},
#  {'src': 'תסבירי לי איך יכול להיות שרבתם, הוא רדף אחרייך החוצה, צעק עלייך, לא ענית, הלכת, ואז מישהו אחר שבר לו את המפרקת והלך?',
#   'mt': "Explain to me how it could be that you argued, he chased you out, yelled at you, you didn't answer, you left, and then someone else broke his neck and left?"},
#  {'src': 'עוד 42 דקות הם מגיעים לגבול הכורדי עם איראן ומשם, 31 דקות לביצוע.',
#   'mt': 'In 42 minutes they reach the Kurdish border with Iran and from there, 31 minutes to execute.'},
#  {'src': 'אתן לך תשובה עוד היום.', 'mt': 'I will give you an answer today.'},
#  {'src': 'אני רוצה לדבר איתו.', 'mt': 'I want to talk to him.'},
#  {'src': 'אתם לא יכולים להיכנס.', 'mt': "You can't come in."},
#  {'src': 'את יודעת איזה בלגן יהיה לי בעבודה אם מישהו ידע שהיא הייתה אצלנו בבית?',
#   'mt': 'Do you know what a mess I would have at work if anyone knew she was at our house?'},
#  {'src': 'היה לו משפט שהיה אומר כל הזמן.',
#   'mt': 'He had a sentence he would say all the time.'},
#  {'src': 'מההתחלה היא נראתה לי חשודה.',
#   'mt': 'From the beginning she seemed suspicious to me.'},
#  {'src': 'בכל מקרה, נראה לי שזה בלתי אפשרי בשבילי.',
#   'mt': "Anyway, I think it's impossible for me."},
#  {'src': 'אני מבין שהגעתם לכאן בטעות.',
#   'mt': 'I understand that you came here by mistake.'},
#  {'src': 'חשבתי שזיהיתי את כתב היד שלה.',
#   'mt': 'I thought I recognized her handwriting.'},
#  {'src': 'אז למה שיקרת בתחקיר?',
#   'mt': 'So why did you lie in the investigation?'},
#  {'src': 'אני מעדיף למות ולא לעזור לך.',
#   'mt': "I'd rather die than help you."},
#  {'src': '"למותך צריכה להיות תכלית.',
#   'mt': '"Your death should have a purpose.'},
#  {'src': 'זה נראה לי יותר טוב.', 'mt': 'It looks better to me.'},
#  {'src': 'אני לא רוצה שהם ידעו שאנחנו מחפשים את הסוכנת שלהם.',
#   'mt': "I don't want them to know we're looking for their agent."},
#  {'src': 'אעלה מחר על המטוס הראשון.',
#   'mt': "I'll get on the first plane tomorrow."},
#  {'src': 'היא במצב לחזור פנימה?', 'mt': 'Is she in a position to go back in?'},
#  {'src': 'שזה כיף להיות פליט?', 'mt': "that it's fun to be a refugee?"},
#  {'src': 'הוא חייב לעשות את זה בעצמו.', 'mt': 'He has to do it himself.'},
#  {'src': 'ואז, במקום להתווכח איתי, היא פשוט התחילה לשיר לי שיר.',
#   'mt': 'And then, instead of arguing with me, she just started singing a song to me.'},
#  {'src': 'אנחנו זקוקים לכל מי שיכול לבוא.',
#   'mt': 'We need everyone who can come.'},
#  {'src': 'הללי, דווח לחיל האוויר.', 'mt': 'Hallie, report to the Air Force.'},
#  {'src': 'בטוח שהישראלים לא יודעים?',
#   'mt': "Are you sure the Israelis don't know?"},
#  {'src': 'אולי יום אחד אעשה את זה בשבילך.',
#   'mt': "Maybe one day I'll do it for you."},
#  {'src': 'לא משנה מה היה קורה איתי, לא הייתי מסכנת את המשפחה שלך.',
#   'mt': "No matter what happened to me, I wouldn't put your family at risk."},
#  {'src': "ז'ילה היא נשמה טובה.", 'mt': 'Jilla is a good soul.'},
#  {'src': 'הנתיב כולו מרושת עכשיו במצלמות.',
#   'mt': 'The entire route is now covered in cameras.'},
#  {'src': 'מטה המודיעין המסכל של משמרות המהפכה -, - טהרן אני רק צריכה לעדכן הרשאות וסיימתי.',
#   'mt': "Revolutionary Guards Frustrating Intelligence Headquarters -, - Tehran I just need to update the permissions and I'm done."},
#  {'src': 'אני לא מאמינה ששחררת אותו.',
#   'mt': "I can't believe you let him go."},
#  {'src': 'תדאג שמסעוד טבריזי יגיע לאיסטנבול ללא פגע בתוך 24 שעות.',
#   'mt': 'Make sure that Saoud Tabrizi arrives in Istanbul unharmed within 24 hours.'},
#  {'src': 'כל הדמויות והאירועים המוצגים בסדרה - - .הינם פיקטיביים לחלוטין כל דמיון לאירועים או אנשים אמיתיים -, - ,חיים או מתים - .הינו מקרי בהחלט - ראזיה.',
#   'mt': 'All the characters and events presented in the series - are completely fictitious - any resemblance to real events or people - -, alive or dead - is absolutely accidental - razia.'},
#  {'src': 'אני לא יכול לדבר איתך על זה.',
#   'mt': "I can't talk to you about it."},
#  {'src': 'הלב שלך במקום הנכון.', 'mt': 'Your heart is in the right place.'},
#  {'src': 'אז מה את אומרת על הסכם הגרעין?',
#   'mt': 'So what do you say about the nuclear agreement?'},
#  {'src': 'התחתנו והחלטנו לחזור לטהרן.',
#   'mt': 'We got married and decided to return to Tehran.'},
#  {'src': 'כנסי לאט לאט פנימה.', 'mt': 'Slowly enter.'},
#  {'src': 'לא היו שום בעיות.', 'mt': 'There were no problems.'},
#  {'src': 'אנחנו חייבים לסגור את הגייט, כולם במטוס מחכים.',
#   'mt': 'We have to close the gate, everyone is on the plane waiting.'},
#  {'src': 'לא היית צריך לעשות את זה.', 'mt': "You shouldn't have done that."},
#  {'src': 'זה היה השיר שלנו.', 'mt': 'That was our song.'},
#  {'src': '- טהרן - - טהרן מטה המודיעין המסכל של משמרות המהפכה - סע.',
#   'mt': '- Tehran - - Tehran Revolutionary Guards Frustrating Intelligence Headquarters - Go.'},
#  {'src': 'אלה מבזבזים חשמל כמו כורי ביטקוין.',
#   'mt': 'These waste electricity like bitcoin miners.'},
#  {'src': 'ככה היא מורידה פרופיל?',
#   'mt': 'Is this how she lowers her profile?'},
#  {'src': 'צדקת, בוס, הייתה התחלפות.',
#   'mt': 'You were right, boss, there was a tradeoff.'},
#  {'src': 'סליחה, אני צריך לענות.', 'mt': 'Sorry, I have to answer.'},
#  {'src': 'הם מתייחסים אליי טוב.', 'mt': 'They treat me well.'},
#  {'src': 'בואי, בואי, תני לי חיבוק.',
#   'mt': 'Come on, come on, give me a hug.'},
#  {'src': 'אני רואה שאתה מחפש ראיות.',
#   'mt': 'I see you are looking for evidence.'},
#  {'src': 'לא ניתן שיטמאו את הרחובות הטהורים" "של טהרן.',
#   'mt': 'The clean streets of Tehran will not be allowed to be polluted.'},
#  {'src': 'הכנתי לנו ארוחת ערב.', 'mt': 'I made us dinner.'},
#  {'src': 'בשעה כזאת בלילה אתה חייב אישור כניסה.',
#   'mt': 'At this time of night you must have an entrance permit.'},
#  {'src': 'אני רק רוצה לישון.', 'mt': 'I just want to sleep.'},
#  {'src': 'לא קוראים לך זהרה, נכון?', 'mt': "Your name isn't Zahra, is it?"},
#  {'src': 'אני צריך לקבל אישור.', 'mt': 'I need to get approval.'},
#  {'src': 'קדוש, אנחנו צריכים אותו.', 'mt': 'A saint, we need him.'},
#  {'src': 'שוב אתה מתחיל עם זה?', 'mt': 'Are you starting with that again?'},
#  {'src': 'חוסרו, קח אותו למעצר.', 'mt': 'Hossaro, take him into custody.'},
#  {'src': 'אתה יודע את מה שסיפרתי למסעוד.',
#   'mt': 'You know what I told Masoud.'},
#  {'src': 'בוא, השארנו גם לך.', 'mt': 'Come, we left for you too.'},
#  {'src': 'אסור לאף אחד לדעת שאני פה.', 'mt': "No one can know I'm here."},
#  {'src': 'אני רוצה לבוא אליכם, לישראל, אבל אמרו בשגרירות שאני לא יהודיה.',
#   'mt': 'I want to come to you, to Israel, but they said in the embassy that I am not Jewish.'},
#  {'src': 'קדוש, זה נראה כמו שורה של שרתי גיבוי.',
#   'mt': 'Holy, it looks like a line of backup singers.'},
#  {'src': 'אפילו לא יום אחד!', 'mt': 'Not even one day!'},
#  {'src': 'זאת המערכת העירונית ששולטת בכל המצלמות באזור.',
#   'mt': 'This is the municipal system that controls all the cameras in the area.'},
#  {'src': 'כשהגעתי לירושלים בפעם הראשונה וראיתי את הכותל הקדוש ואת החומות שבנו המוסלמים, פרצתי בבכי.',
#   'mt': 'When I arrived in Jerusalem for the first time and saw the Holy Wall and the walls built by the Muslims, I broke down in tears.'},
#  {'src': 'נאהיד, את מוכרחה להאמין לי ולהסביר את זה לבעלך.',
#   'mt': 'Nahid, you have to believe me and explain this to your husband.'},
#  {'src': 'המהנדס מחברת החשמל זיהה את הבחורה.',
#   'mt': 'The engineer from the electric company identified the girl.'},
#  {'src': 'להגיד לך את האמת.', 'mt': 'tell you the truth.'},
#  {'src': 'אני דואג בגלל מחירה של השרשרת שאת מסתכלת עליה.',
#   'mt': "I'm worried because of the price of the necklace you're looking at."},
#  {'src': 'תקשיבי, כמה מכירות וזה יהיה מאחורינו.',
#   'mt': 'Listen, a few sales and it will be behind us.'},
#  {'src': 'זה כל כך יפה לך.', 'mt': 'It is so beautiful to you.'},
#  {'src': 'נראה לי שהוא חזר פנימה.', 'mt': 'I think he went back in.'},
#  {'src': 'ייתכן שגורמים זרים מנסים לפרוץ לשרתים האלה ולהיכנס למערכות צבאיות.',
#   'mt': 'It is possible that foreign parties are trying to break into these servers and enter military systems.'},
#  {'src': 'חאמינאי הוא המנהיג שלנו, הוא יורשו של הנביא.',
#   'mt': 'Khamenei is our leader, he is the successor of the Prophet.'},
#  {'src': 'מגדל, את שומעת אותי?', 'mt': 'Magdel, can you hear me?'},
#  {'src': 'מה אם היו עוצרים אותך?', 'mt': 'What if they arrested you?'},
#  {'src': 'בוקר טוב גם לך.', 'mt': 'Good morning to you too.'},
#  {'src': 'כנציג החברה, אני מחויב לערוך סיור בבית, לוודא שהתמונות שהעלית תואמות למצב הנתון.',
#   'mt': 'As a representative of the company, I am obliged to conduct a tour of the house, to make sure that the photos you uploaded correspond to the given situation.'},
#  {'src': 'איך זה בכלל קרה?', 'mt': 'How did this even happen?'},
#  {'src': 'תעלה ותגיד להם שיחלישו קצת את המוזיקה.',
#   'mt': 'Go up and tell them to tone down the music a bit.'},
#  {'src': 'כשאת מגיעה לבית מסתור- תפעילי נוהל פינוי ושמוחמד ייפטר מהבחור האיראני.',
#   'mt': 'When you arrive at the safe house, activate an evacuation procedure and have Muhammad get rid of the Iranian guy.'},
#  {'src': 'עצרו את פרוויז לפני שבוע.', 'mt': 'Pervez was arrested a week ago.'},
#  {'src': 'הניתוח יחל בעוד שעתיים.',
#   'mt': 'The surgery will start in two hours.'},
#  {'src': 'אבל אנחנו מובטלים, והתארים האלה שווים לתחת.',
#   'mt': "But we're unemployed, and these degrees suck."},
#  {'src': 'אשאר רק לילה אחד.', 'mt': 'I will only stay one night.'},
#  {'src': 'הזעיקו אותו לאיזו תקלה.',
#   'mt': 'They summoned him for some trouble.'},
#  {'src': 'יש דברים שלא חוסכים בהם.', 'mt': 'Some things are not saved.'},
#  {'src': 'אני לא יכול להבטיח לך את זה.', 'mt': "I can't promise you that."},
#  {'src': 'הוא בחיים לא ייתן שמשהו יקרה לך.',
#   'mt': 'He will never let anything happen to you.'},
#  {'src': 'עברו כמעט שנתיים מאז שחזרנו.',
#   'mt': "It's been almost two years since we returned."},
#  {'src': 'אני לא יודע, אבל זה היה קל מדי.',
#   'mt': "I don't know, but it was too easy."},
#  {'src': 'כפי שאמרתי, אשתך בידיים טובות.',
#   'mt': 'As I said, your wife is in good hands.'},
#  {'src': 'לאלה שרוצים להפוך את האוניברסיטה לבית השימוש של הקפיטליסטים.',
#   'mt': 'For those who want to turn the university into the toilet of the capitalists.'},
#  {'src': 'הם אמרו לי שחטפת מישהו, אזרח ישראלי, ושאיימת להרוג אותו.',
#   'mt': 'They told me that you kidnapped someone, an Israeli citizen, and that you threatened to kill him.'},
#  {'src': 'לישראלים יש עיניים ואוזניים בטהרן.',
#   'mt': 'The Israelis have eyes and ears in Tehran.'},
#  {'src': 'הללי, תודיע למח"א שימשיכו, אנחנו נעמוד בזמן.',
#   'mt': "Haley, tell the MPA to continue, we'll stand on time."},
#  {'src': 'אתם בדיוק כמו משמרות המהפכה הפושעים.',
#   'mt': 'You are just like the criminal Revolutionary Guards.'},
#  {'src': 'בשביל מי את עובדת, יסמין?', 'mt': 'Who do you work for, Yasmin?'},
#  {'src': 'הלכת אל הרופא שהמלצתי לך עליו?',
#   'mt': 'Did you go to the doctor I recommended to you?'},
#  {'src': 'רציתי לעדכן אותך שאנחנו לא היחידים שמחפשים את הנסיכה.',
#   'mt': 'wanted to update you that we are not the only ones looking for the princess.'},
#  {'src': 'שימי אותה באוטו ותעופו משם.',
#   'mt': 'Put her in the car and fly away.'},
#  {'src': 'המשבש שלו מופעל, אין עדיין איכון של השיחה.',
#   'mt': 'His disruptor is activated, there is still no reconfiguration of the call.'},
#  {'src': 'אם תעני לי על השאלה הזו.', 'mt': 'If you answer me this question.'},
#  {'src': 'יש סיכוי שהאנשים של פראז הגיעו לשם בגללך?',
#   'mt': "Is there any chance that Faraz's people got there because of you?"},
#  {'src': 'אתה צריך להבטיח לי, גורב, שתגן על אשתי ועל הילדים.',
#   'mt': 'You have to promise me, Gorb, that you will protect my wife and children.'},
#  {'src': '-את יוצרת קשר עכשיו עם המקור שלך, ומשכנעת אותו שיכניס אותנו לבסיס הנ"מ הלילה.',
#   'mt': '- You contact your source now, and convince him to let us into the NIM base tonight.'},
#  {'src': 'יש מצב שנקבל מחר אור ירוק.',
#   'mt': 'There is a situation where we will get a green light tomorrow.'},
#  {'src': 'הייתי צריך לטוס איתך, הייתי צריך לדאוג לך.',
#   'mt': 'I should have flown with you, I should have taken care of you.'},
#  {'src': 'הוא היה היום בדירה של קייסר.',
#   'mt': "He was at Kaiser's apartment today."},
#  {'src': 'למה הוא עשה את זה?', 'mt': 'Why did he do this?'},
#  {'src': 'אבל לפני שהצלחתי לעשות משהו.',
#   'mt': 'But before I could do anything.'},
#  {'src': "הוא הטריד את ז'ילה.", 'mt': 'He harassed Jilla.'},
#  {'src': 'מי עשה לך את זה?', 'mt': 'who did this to you'},
#  {'src': 'שלח שני צוותים שיעקבו אחריו.',
#   'mt': 'Send two teams to follow him.'},
#  {'src': 'אתה יודע כמה סיפורים כאלה אני שומע כל יום?',
#   'mt': 'Do you know how many stories like this I hear every day?'},
#  {'src': 'הבחורה השנייה היא כנראה הסוכנת שאנחנו מחפשים.',
#   'mt': "The other girl is probably the agent we're looking for."},
#  {'src': 'את בישלת את כל זה?', 'mt': 'did you cook all this'},
#  {'src': 'בחייך, ספר לי אחת.', 'mt': 'Come on, tell me one.'},
#  {'src': 'את זוכרת אותם, כן?', 'mt': 'You remember them, yes?'},
#  {'src': 'את צריכה להגיד תודה שהוא עוד בחיים.',
#   'mt': "You should be thankful he's still alive."},
#  {'src': 'סליחה שאני אומר, אבל יש לך קצת מבטא.',
#   'mt': 'Sorry to say, but you have a bit of an accent.'},
#  {'src': '"זה מקום מצוין למסיבה".', 'mt': '"This is a great place to party".'},
#  {'src': 'הרגשה כל כך טובה.', 'mt': 'Feels so good.'},
#  {'src': 'טוב, אז מה זה הדבר הסודי שאתה צריך ממני?',
#   'mt': 'Well, then what is this secret thing you need from me?'},
#  {'src': 'גברת סולטאני, שתהיה לך נסיעה טובה.',
#   'mt': 'Mrs. Sultan, have a safe trip.'},
#  {'src': 'הם רואים את המטוסים.', 'mt': 'They see the planes.'},
#  {'src': '- איסטנבול, טורקיה - בוקר טוב, אדוני.',
#   'mt': '- Istanbul, Turkey - Good morning, sir.'},
#  {'src': 'אנחנו עדיין מנסים לברר לאן הוא נסע משדה התעופה, אבל אנחנו מניחים שלאחד המלונות באיסטנבול.',
#   'mt': 'We are still trying to find out where he went from the airport, but we assume to one of the hotels in Istanbul.'},
#  {'src': 'תחנות הרדיו והטלוויזיה נמצאות שם.',
#   'mt': 'The radio and TV stations are there.'},
#  {'src': 'אתקשר אליך מאוחר יותר.', 'mt': "I'll call you later."},
#  {'src': 'רק תגיד לי אם אתה יכול להשיג לי או לא.',
#   'mt': 'Just tell me if you can get me or not.'},
#  {'src': 'אבל דווקא כשעליתי לישראל, הרגשתי זרה.',
#   'mt': 'But when I went to Israel, I felt like a stranger.'},
#  {'src': 'היא ילדה טובה, קצת פחדנית.',
#   'mt': "She's a good girl, a little chicken."},
#  {'src': 'היא אמרה שזה רק ללילה.',
#   'mt': 'She said it was only for the night.'},
#  {'src': 'האובייקט נוסע לכיוון ההפגנה של הסטודנטים.',
#   'mt': 'The object is driving towards the student demonstration.'},
#  {'src': 'לכי לטור אר-6, זה בקצה הדרומי.',
#   'mt': "Go to row R-6, it's at the southern end."},
#  {'src': 'זה היה כתוב בשמיים.', 'mt': 'It was written in heaven.'},
#  {'src': 'פרהאם ביטל את הדיווח על התקלה.',
#   'mt': 'Fahram cancelled the report of the malfunction.'},
#  {'src': 'אני לא חושבת שאני יכולה לעזור לך.',
#   'mt': "I don't think I can help you."},
#  {'src': 'אני מנסה להציל אותך.', 'mt': "I'm trying to save you."},
#  {'src': 'תראה לאן הוא הולך.', 'mt': "Look where he's going."},
#  {'src': 'לכבוד הוא לי, אדוני.', 'mt': 'It is an honor, sir.'},
#  {'src': 'בואו נראה להם מי אנחנו.', 'mt': "Let's show them who we are."},
#  {'src': '"הם יודעים על "הנסיכה.', 'mt': '"They know about "the princess.'},
#  {'src': 'אני מבין שזה דחוף.', 'mt': "I understand it's urgent."},
#  {'src': 'מאיפה בכלל הקרצת אותה?', 'mt': 'Where did you even get it?'},
#  {'src': 'אבל יש לי בדיחות טובות.', 'mt': 'But I have good jokes.'},
#  {'src': 'קבוצות מחוברות זו לזו.',
#   'mt': 'Groups are connected to each other.'},
#  {'src': 'תגיד להם שאני ממודיעין משמרות המהפכה.',
#   'mt': 'Tell them I am from the Revolutionary Guards intelligence.'},
#  {'src': 'תעשי את זה מהר.', 'mt': 'Do it fast.'},
#  {'src': 'אני לא יכול לעשות את זה בשבילך.', 'mt': "I can't do it for you."},
#  {'src': 'העיניים אך ורק אליי מעכשיו.', 'mt': 'Eyes only at me from now on.'},
#  {'src': 'מה דעתך על השעה אחת?', 'mt': 'How about one hour?'},
#  {'src': 'מילאד הוא איש מחשבים.', 'mt': 'Milad is a computer man.'},
#  {'src': 'אבל העברתי עותק למחלקת הסייבר שלנו ותוך כמה שעות נוכל להבין מה היא ניסתה לעשות שם.',
#   'mt': 'But I forwarded a copy to our cyber department and in a few hours we will be able to understand what she was trying to do there.'},
#  {'src': 'יש לי משפחה, יש לי ילדה.', 'mt': 'I have a family, I have a girl.'},
#  {'src': 'ניסינו כל גישה אפשרית, אך הוא הכחיש שיש לו קשר למוסד.',
#   'mt': 'We tried every possible approach, but he denied having any connection to the institution.'},
#  {'src': 'אני מחפש את הבת שלי.', 'mt': "I'm looking for my daughter."},
#  {'src': 'הקטע עם המצלמות, עפתי על זה.',
#   'mt': 'The thing with the cameras, I fell for it.'},
#  {'src': 'חסן אמר שלא יעשו להם כלום.',
#   'mt': 'Hassan said they would not do anything to them.'},
#  {'src': 'שאהין, מה קורה פה?', 'mt': "Shaheen, what's going on here?"},
#  {'src': 'בוא נעשן משהו ונדפוק את הראש.',
#   'mt': "Let's smoke something and screw our heads up."},
#  {'src': 'תשאירי אצלך, זה בסדר.', 'mt': "Keep it, it's fine."},
#  {'src': 'דברי אל הלב שלו, אבל לא מהלב שלך.',
#   'mt': 'Talk to his heart, but not from your heart.'},
#  {'src': '"רוב האנשים פשוט אומרים "הלו.',
#   'mt': '"Most people just say "hello.'},
#  {'src': 'אנחנו כבר מגיעים לשם.', 'mt': "We're already getting there."},
#  {'src': 'תמר, תתפסי לו את הרגליים.', 'mt': 'Tamar, grab his legs.'},
#  {'src': 'הוא באמת ביטל אותה.', 'mt': 'He really canceled it.'},
#  {'src': 'אמרתי לך שהכול יהיה בסדר.',
#   'mt': 'I told you everything would be fine.'},
#  {'src': 'הוא השאיר לך מכתב שבו הוא מסביר הכל.',
#   'mt': 'He left you a letter in which he explains everything.'},
#  {'src': 'מספר סידורי של המזגן.',
#   'mt': 'Serial number of the air conditioner.'},
#  {'src': 'הוא היה מטר אחד ממנה!', 'mt': 'He was one meter from her!'},
#  {'src': 'בכל מקרה, אנחנו חייבים להיות מוכנים לפעולה בכל רגע נתון.',
#   'mt': 'In any case, we must be ready for action at any given moment.'},
#  {'src': 'למרות שאני זה שאזוק למיטה, מבין שנינו, אני החופשי.',
#   'mt': "Even though I'm the one who's chained to the bed, of the two of us, I'm free."},
#  {'src': 'כואב לי שאת מדברת בשמם.',
#   'mt': 'It hurts me that you are speaking on their behalf.'},
#  {'src': 'היא למדה שם בבית ספר לזרים.',
#   'mt': 'She studied there at a school for foreigners.'},
#  {'src': 'לאן אתה לוקח אותי?', 'mt': 'where are you taking me'},
#  {'src': 'לא מבשלת הרבה כמו פעם.', 'mt': "I don't cook as much as I used to."},
#  {'src': '- פארק לאלה - - אוניברסיטת טהרן למדעי הרפואה - אתה מהמשטרה?',
#   'mt': '- Lelah Park - - Tehran University of Medical Sciences - Are you from the police?'},
#  {'src': 'מתי אני חוזרת הביתה?', 'mt': 'when do i come home'},
#  {'src': 'אני מתכוונת שאתה חופשי ללכת.', 'mt': "I mean you're free to go."},
#  {'src': 'עכשיו תורך להוכיח לי.',
#   'mt': "Now it's your turn to prove it to me."},
#  {'src': 'אני אקנה במיליון טומאן, אם הסחורה טובה.',
#   'mt': 'I will buy for a million tomans, if the goods are good.'},
#  {'src': 'הייתי בדיוק באותו מצב.',
#   'mt': 'I was in exactly the same situation.'},
#  {'src': 'רואה חופה, רואה חופה, אלף רגל מתחתיי, צפון-מזרח.',
#   'mt': 'Voir Hute, Voir Hute, a thousand feet below me, northeast.'},
#  {'src': 'מה היא עשתה לך?', 'mt': 'what did she do to you'},
#  {'src': 'ידעתי שיהיה לזה מחיר.', 'mt': 'I knew it would have a price.'},
#  {'src': 'את ישבת איתו בחדר.', 'mt': 'You sat in the room with him.'},
#  {'src': 'תזכירי לי, איפה את גרה?', 'mt': 'Remind me, where do you live?'},
#  {'src': 'תמר, זה אני, "העיט.', 'mt': 'Tamar, it\'s me, "The Eagle.'},
#  {'src': 'תכף נדבר על הכול, טוב?',
#   'mt': "We'll talk about everything soon, okay?"},
#  {'src': 'אחותי שלחה לי אותך.', 'mt': 'My sister sent you to me.'},
#  {'src': 'אל תפיץ את הסרטון ההוא.', 'mt': "Don't distribute that video."},
#  {'src': 'נתתי לו מכה והוא התקפל.', 'mt': 'I hit him and he folded.'},
#  {'src': 'כלום, היא בעטה לי בביצים.',
#   'mt': 'Nothing, she kicked me in the balls.'},
#  {'src': 'למה אתם לא מצליחים לקלוט את זה?',
#   'mt': "Why can't you understand that?"},
#  {'src': 'אתה יודע טוב מאוד מה אני.', 'mt': 'You know very well what I am.'},
#  {'src': 'תגיד לבנות לבוא, לא לבנים.',
#   'mt': 'Tell the girls to come, not the boys.'},
#  {'src': 'אתה בנמל התעופה עם אשתך בדרך לפריז, לא?',
#   'mt': "You're at the airport with your wife on the way to Paris, aren't you?"},
#  {'src': 'תעשה את מה שאנחנו אומרים לך.', 'mt': 'Do what we tell you.'},
#  {'src': 'תרשה לי לעזור לך.', 'mt': 'let me help you'},
#  {'src': "זאת באמת אני, קולוצ'ה.", 'mt': "It's really me, Kolocha."},
#  {'src': 'אני צריכה אותו בחדר השרתים.',
#   'mt': 'I need him in the server room.'},
#  {'src': 'ואל תקשיב לאף אחד.', 'mt': "And don't listen to anyone."},
#  {'src': 'למה עשית את זה?', 'mt': 'why did you do that?'},
#  {'src': 'כי הוא לא נותן לנו לעבוד.', 'mt': "Because he won't let us work."},
#  {'src': 'אני לא מאמין למילה אחת שיוצאת לך מהפה, ואין סיכוי שאני עוזר לך יותר בכלום!',
#   'mt': "I don't believe a word that comes out of your mouth, and there's no way I'm helping you with anything anymore!"},
#  {'src': 'זה אחד השמות הבדויים של פראז כמאלי.',
#   'mt': "It's one of Farraz Kamli's pseudonyms."},
#  {'src': 'שמעת כבר את כולן.', 'mt': "You've heard them all."},
#  {'src': 'היא המשיכה לחשוב עלייך.', 'mt': 'She kept thinking about you.'},
#  {'src': 'זה היה לילה אחד, הם גירשו אותה כששמעו.',
#   'mt': 'It was one night, they deported her when they heard.'},
#  {'src': 'איך אתה לא מבין את זה?', 'mt': 'how do not you understand this?'},
#  {'src': 'היא פשוט נכנסה וקפצה?', 'mt': 'She just came in and jumped?'},
#  {'src': 'התחיל לכאוב לי הראש.', 'mt': 'My head started to hurt.'},
#  {'src': 'אם את לא תעשי זאת, אני אעשה.', 'mt': "If you don't do it, I will."},
#  {'src': "היה לנו פנצ'ר בדרך.", 'mt': 'We had a flat tire on the way.'},
#  {'src': 'אסור שהיא תספר להם על זה.',
#   'mt': 'She must not tell them about it.'},
#  {'src': 'כי לעולם לא תראה אותן יותר.',
#   'mt': 'Because you will never see them again.'},
#  {'src': 'אני מסיים כאן ובא.', 'mt': 'I finish here and next.'},
#  {'src': 'מה היא חיפשה שם בכלל?',
#   'mt': 'What was she even looking for there?'},
#  {'src': 'טוב, אני אמשיך לארוז.', 'mt': "Well, I'll keep packing."},
#  {'src': 'בוא נתקדם לנתיב הכניסה.',
#   'mt': "Let's move on to the entrance path."},
#  {'src': 'היא חוזרת למשפחה שלה בקטאר.',
#   'mt': 'She returns to her family in Qatar.'},
#  {'src': 'ראיתי אותו גם אתמול בערב, רודף אחרי הנסיכה.',
#   'mt': 'I saw him also last night, chasing the princess.'},
#  {'src': 'את רוצה לשתות משהו?', 'mt': 'do you want something to drink'},
#  {'src': 'את מעדיפה שנדבר באנגלית?',
#   'mt': 'Would you rather we speak English?'},
#  {'src': 'הניתוח יעבור בשלום מחר, אינשאללה.',
#   'mt': 'The surgery will go well tomorrow, inshallah.'},
#  {'src': 'נוצר חלון הזדמנויות צר.',
#   'mt': 'A narrow window of opportunity has been created.'},
#  {'src': 'מסתבר שחלק מהשרתים בתחנה מחוברים למערכות צבאיות.',
#   'mt': 'It turns out that some of the servers at the station are connected to military systems.'},
#  {'src': 'אתם כבר מזמן איבדתם את המצפון שלכם.',
#   'mt': 'You have long lost your conscience.'},
#  {'src': '- .אל תגידי כלום על מה שקרה איתו - שרה פרהמנד!',
#   'mt': "- Don't say anything about what happened to him - Sarah Fahramand!"},
#  {'src': 'לאשתו קוראים ארזו, הם בני 50 ומשהו.',
#   'mt': "His wife's name is Erzo, they're 50 and something."},
#  {'src': 'יכולנו לפתור את זה בדרך אחרת.',
# ...
#  {'src': 'השאלה החשובה שעל הפרק היא, מה תהיה התגובה האיראנית?',
#   'mt': 'The important question at hand is, what will be the Iranian reaction?'},
#  {'src': 'לסיכום, מומלץ לישראל לא להתנגד אוטומטית לכל נורמליזציה מצרית-איראנית, אלא לחתור לכך שתכולתה תעלה בקנה אחד עם האינטרסים הישראליים.',
#   'mt': 'In conclusion, it is recommended that Israel not automatically oppose any Egyptian-Iranian normalization, but strive to ensure that its capabilities will be in line with Israeli interests.'},
#  {'src': 'שיח אלופים — בחלוף חמישים שנה',
#   'mt': 'Champions Discussion  Over the past fifty years'},
#  {'src': 'הגל השני של מגפת הקורונה פגע גם באוכלוסייה ובכלכלה הפלסטינית.',
#   'mt': 'The second wave of the coronavirus pandemic also affected the Palestinian population and economy.'},
#  {'src': 'לאורך כשבעים שנה, ממשלים רפובליקאים ודמוקרטים כאחד, הביעו מחויבות לשמירה על ביטחון הממלכה.',
#   'mt': 'For nearly 70 years, Republican and Democratic governments alike have expressed a commitment to maintaining the security of the kingdom.'},
#  {'src': 'בכל מקרה, ספק אם רצונו של ביידן להחזיר ליחסי ארצות הברית-רוסיה יציבות ויכולת לחזות מראש צעדים תתממש עקב האינטרס המנוגד של פוטין.',
#   'mt': "In any case, it is doubtful whether Biden's desire to restore stability and foresight to U.S.-Russia relations will be realized due to Putin's conflicting interest."},
#  {'src': 'עם זאת, נראה שמכלול הגורמים גורם צורך לתמרן מול עומס יתר של סיכונים, שסבירות התממשותם תעלה ככל שתימשך הפעילות הישראלית.',
#   'mt': 'However, it seems that the combination of factors makes it necessary to maneuver in the face of an overabundance of risks, the likelihood of which will increase as long as the Israeli operation continues.'},
#  {'src': 'חשוב מכך, שוב ושוב הוכח בעבר שהשפעתו של "הרחוב הערבי" של ממשלותיו מוגבלת.',
#   'mt': 'More importantly, it has been proven time and again in the past that the influence of the "Arab street" of its governments is limited.'},
#  {'src': 'סביר שסין ורוסיה יהיו פחות נרגזות ממתקפה ישראלית מאשר ממתקפה אמריקנית, ואולי נכונות יותר להשתתף במניעת ההסלמה שאחרי.',
#   'mt': 'It is likely that China and Russia will be less upset by an Israeli attack than by an American one, and perhaps more willing to participate in preventing a subsequent escalation.'},
#  {'src': 'אם תתמוך ברוסיה, תסכן את יחסיה החשובים עם אירופה וארצות הברית וכן את מיתוג מעמדה כמעצמה אחראית שמקדמת שלום בעולם.',
#   'mt': 'If you support Russia, you will risk its important relations with Europe and the United States as well as its position as a responsible power that promotes peace in the world.'},
#  {'src': 'אם כך יקרה, גם האופציה הצבאית האמריקאית תחזור ותעלה על השולחן, ובכך תיתן גיבוי לאופציה הישראלית.',
#   'mt': 'If this happens, the American military option will also return and come up on the table, thus providing backup for the Israeli option.'},
#  {'src': 'בחודש מאי 2009, עמד האנטסמן בראש משלחת סחר לישראל, שנועדה להרחיב את "היחסים האסטרטגיים" בין יוטה לבין ישראל.',
#   'mt': 'In May 2009, Huntsman headed a trade delegation to Israel, which was intended to expand the "strategic relations" between Utah and Israel.'},
#  {'src': "תוצאות הבחירות לנשיאות טורקיה שנערכו ב-14 במאי היו ניצחון גדול לנשיא המכהן, רג'פ טאיפ ארדואן, ואכזבה קשה לאופוזיציה.",
#   'mt': 'The results of the presidential election held in Turkey on May 14 were a major victory for the incumbent president, Recep Tayyip Erdogan, and a major disappointment for the opposition.'},
#  {'src': 'זה היה גם המסר המוביל בדוח ועדת אור, שהוקמה בעקבות המהומות הקשות של אוקטובר 2000.',
#   'mt': 'This was also the leading message in the report of the Commission of Light, established in the aftermath of the severe riots of October 2000.'},
#  {'src': 'הבעיה האופרטיבית המדאיגה ביותר, שנחשפה גם בתרגיל הנוכחי, למרות הדיבורים על שיפור, קשורה לסוגיית התיאום הבין-מערכתי.',
#   'mt': 'The most worrying operational problem, which was also revealed in the current exercise, despite the talk of improvement, is related to the issue of intersystemic coordination.'},
#  {'src': 'בשלב זה, שליחו של ראש הממשלה נתניהו, שנשלח לוושינגטון לדון בנושא הזה עם הממשל, לא הצליח להגיע להסכם עם הצד האמריקאי.',
#   'mt': "At this point, Prime Minister Netanyahu's envoy, who was sent to Washington to discuss this issue with the government, was unable to reach an agreement with the American side."},
#  {'src': 'איראן פועלת לפתח ולממש אסטרטגיה לפעולה במרחב הסייבר.',
#   'mt': 'Iran is working to develop and implement a strategy for action in cyberspace.'},
#  {'src': 'קריאות בנוסח "שמרנים, רפורמיסטים, הסיפור נגמר עבור כולכם" מעידות על אובדן אמון מצד הציבור כלפי שני המחנות הפוליטיים המרכזיים כאחד.',
#   'mt': 'Calls in the format "conservatives, reformists, the story is over for all of you" indicate a loss of confidence on the part of the public towards both main political camps alike.'},
#  {'src': 'תפיסה זו לא סיפקה תשתית ידע מספקת ללחימה רחבה ומשולבת, כמו למשל בלבנון.',
#   'mt': 'This perception did not provide a sufficient knowledge infrastructure for a broad and integrated war, such as in Lebanon.'},
#  {'src': 'יתר על כן, ניכר כי לפחות חלקים בציבור האיראני מוכנים להסתפק – לפחות בטווח הקצר – בשיפור המצב הכלכלי.',
#   'mt': 'Furthermore, it is apparent that at least sections of the Iranian public are ready to be satisfied  at least in the short term with the improvement of the economic situation.'},
#  {'src': 'אני רוצה להודות לכל מי שעבד על התכנית, ולכל צוות המכון, שעושים עבודה טובה לאורך השנה.',
#   'mt': 'I want to thank everyone who worked on the program, and the entire staff of the institute, who do a good job throughout the year.'},
#  {'src': 'הנשקל – הפצת פייק ניוז מ- 2013.',
#   'mt': 'The balance  Distribution of Pike News from 2013.'},
#  {'src': 'אם בין השנים 2012 – 2016 עמד ייצוא האמל"ח של ארצות הברית לאזור על 47 אחוזים מסך כלל הייצוא האמריקאי, בין 2017 ל-2021 ירד ההיקף ל-43 אחוזים.',
#   'mt': 'If between 2012 and 2016 the export of U.S. goods to the region amounted to 47 percent of total U.S. exports, between 2017 and 2021 the volume decreased to 43 percent.'},
#  {'src': 'הילרי קלינטון אמנם ניצחה טכנית, אך היה זה רחוק מההובלה הבולטת ממנה נהנתה אך שבועות ספורים קודם כן.',
#   'mt': 'Hillary Clinton did win technically, but it was far from the prominent lead she enjoyed just a few weeks earlier.'},
#  {'src': 'איראן היא המדינה החמישית בעולם, והראשונה במזרח התיכון, במספר המתים כתוצאה ממגפת הקורונה.',
#   'mt': 'Iran is the fifth country in the world, and the first in the Middle East, in the number of deaths due to the coronavirus pandemic.'},
#  {'src': 'אחת הבעיות נובעת מכך שיש בלבול בין המונחים פיצוי, תגמול ושכר, שנודעת להם משמעות מעבר להגדרה עצמה.',
#   'mt': 'One of the problems stems from the fact that there is confusion between the terms compensation, reward and salary, which have a meaning beyond the definition itself.'},
#  {'src': 'סרטון INSS: מהם האינטרסים המעורבים ביחסי ישראל-טורקיה?',
#   'mt': 'INSS video: What are the interests involved in Israel-Turkey relations?'},
#  {'src': 'הסכם ה-RCEP ייכנס לתוקף לאחר שיאושרר על ידי כל המדינות החברות - תהליך הצפוי להימשך כשנתיים.',
#   'mt': 'The RCEP agreement will enter into force after being ratified by all partner countries - a process expected to take two years.'},
#  {'src': 'בשנים האחרונות מתרבים הניסיונות של מדינות זרות להשפיע על התהליכים הדמוקרטיים במדינות יריבות להן.',
#   'mt': 'In recent years, the attempts of foreign countries to influence the democratic processes in their rival countries have multiplied.'},
#  {'src': 'קונקרטית, הסינים קשרו בעבר בין שיתוף פעולה עם ארצות הברית בסוגיה האיראנית לבין הקלה במדיניות האמריקאית כלפי סין בסוגיית טאיוואן.',
#   'mt': 'Concretely, the Chinese have in the past linked cooperation with the United States on the Iranian issue to easing American policy towards China on the Taiwan issue.'},
#  {'src': 'כל מדיניות אחרת עלולה להביא למשבר ביחסים בין המדינות והיא בעלת השלכות חמורות על הסביבה האסטרטגית של ישראל.',
#   'mt': "Any other policy could lead to a crisis in relations between the countries and has serious consequences for Israel's strategic environment."},
#  {'src': 'ביטחון תעסוקה הוא האתגר הכלכלי המרכזי – חיוני לנצל את המשבר להשבחת שוק העבודה ולהעלאת הפריון.',
#   'mt': 'Employment security is the main economic challenge  It is essential to use the crisis to boost the labor market and increase fertility.'},
#  {'src': 'בולטת בין הנפגעות מצרים, עקב הפחתת התעבורה בתעלת סואץ כתוצאה מצמצום הסחר הבינלאומי והתיירות.',
#   'mt': 'Notable among the victims is Egypt, due to the decrease in traffic in the Suez Canal as a result of the reduction in international trade and tourism.'},
#  {'src': 'יושב ראש ועדת הבחירות המרכזית יקבע את דרכי הפרסום.',
#   'mt': 'The chairman of the Central Election Commission will determine the methods of publication.'},
#  {'src': 'לצורך כך, הממשלה מתכוונת להוריד חסמים ולקדם את התחרות בשוק.',
#   'mt': 'To this end, the government intends to lower barriers and promote competition in the market.'},
#  {'src': 'זאת נוכח התגברות הביקורת הפנימית על חלקו בקריסתה הכלכלית והפוליטית של לבנון ובמיוחד לקראת הבחירות האמורות להיערך במדינה ב-15 במאי.',
#   'mt': "This is in the face of increased internal criticism for his role in Lebanon's economic and political crisis and especially ahead of the elections due to be held in the country on May 15."},
#  {'src': 'אולם, ספק אם הממשל האמריקאי הנוכחי יהיה "נדיב" כקודמו בהקשר זה.',
#   'mt': 'However, it is doubtful whether the current American administration will be as "generous" as before in this regard.'},
#  {'src': 'מתפתחת מגמה המצביעה על העדפת המסגרת המצומצמת – העדתית, השבטית, הקהילתית, המשפחתית – על פני זו המדינתית.',
#   'mt': 'A trend is developing that indicates the preference of the reduced framework  ethnic, tribal, communal, family  over the state one.'},
#  {'src': 'במישור האזורי: סין והמזרח התיכון',
#   'mt': 'On the regional level: China and the Middle East'},
#  {'src': 'המחבר עוסק בבחינת סוגיות אלה שהן פוטנציאל לחיכוך.',
#   'mt': 'The author deals with examining those issues that are friction potential.'},
#  {'src': 'אשר לחסם הראשון, ניתן להצביע על מגמות שינוי רלוונטיות.',
#   'mt': 'As for the first barrier, it is possible to point out relevant change trends.'},
#  {'src': 'הגוש המערבי מצוי בנסיגה הן במזרח התיכון והן בעולם כולו ובמצב המתהווה צפוי האסלאם לגבור על המערב.',
#   'mt': 'The Western bloc is in retreat both in the Middle East and in the whole world and in the emerging situation that Islam is expected to prevail over the West.'},
#  {'src': 'צמצום התחלואה חיונית להשגת המטרה של "שיטוח העקומה", אך הצפי הוא כי עם שחרור ההגבלות תשוב התחלואה ותעלה.',
#   'mt': 'Reducing morbidity is essential to achieving the goal of "flattening the curve", but it is expected that with the release of the restrictions, morbidity will return and increase.'},
#  {'src': 'אין זו הפתעה שחמאס, המכין את עצמו בימים אלו לעימות הבא עם ישראל, משקיע מאמץ מרוכז בחפירת מנהרות.',
#   'mt': 'It is no surprise that Hamas, which is preparing itself these days for the next conflict with Israel, is investing a concentrated effort in digging tunnels.'},
#  {'src': 'סביר, כי ההצהרה מיועדת גם לרצות את בסיס התמיכה האוונגליסטי של טראמפ לקראת שנת הבחירות בארצות הברית ולסייע לנתניהו במגרש הפוליטי הישראלי.',
#   'mt': "It is likely that the statement is also intended to appease Trump's evangelical support base ahead of the election year in the United States and to assist Netanyahu in the Israeli political arena."},
#  {'src': 'מאמרים שפורסמו לאחרונה בארץ ובעולם העלו ספקות ביחס למספר הרקטות שיירטה "כיפת ברזל" במהלך מבצע "עמוד ענן".',
#   'mt': 'Articles recently published in Israel and around the world raised doubts regarding the number of rockets fired at "Iron Dome" during Operation "Pillar of Cloud".'},
#  {'src': 'פיקוח פרלמנטרי ושיפוטי על הממשלה',
#   'mt': 'Parliamentary and judicial oversight of the government'},
#  {'src': 'ממשל הנשיא ביידן, אף שלא היה האב הביולוגי שלהם, אימץ את "הסכמי אברהם".',
#   'mt': 'The administration of President Biden, although he was not their biological father, adopted the "Abrahamic Agreements".'},
#  {'src': 'הבולט לעין במקרה זה הוא דווקא השוני שבגישה הרוסית לטרור בביתם, לעומת יחסם לגורמים אסלאמיים רדיקלים בחו"ל.',
#   'mt': 'What stands out in this case is precisely the difference in the Russian approach to terrorism at home, compared to its attitude to radical Islamic elements abroad.'},
#  {'src': 'לסיכום, ישראל הסכימה בשנת 2000 לתנאים אותם דרש האו"ם.',
#   'mt': 'In conclusion, Israel agreed in 2000 to the conditions demanded by the UN.'},
#  {'src': 'ההצעה האיראנית באה בתגובה לבקשות מצד מדינות ה-P5+1 לנהל שיחות בסוגיית הגרעין, ואולם, היה חסר בה מרכיב מפתח: התייחסות כלשהי לתוכנית הגרעין של איראן.',
#   'mt': "The Iranian proposal came in response to requests from the P5+1 countries to hold talks on the nuclear issue, but it was missing a key element: some reference to Iran's nuclear program."},
#  {'src': 'יחסי הערים, בעידוד שגרירות סין בישראל, כללו חילופי משלחות ומזכרי הבנות בנושאים עסקיים, כלכליים ותרבותיים.',
#   'mt': 'Relations between the cities, encouraged by the Chinese embassy in Israel, included exchanges of delegations and female secretaries on business, economic and cultural issues.'},
#  {'src': 'בין היתר, הריק השלטוני בא לידי ביטוי בהעדפת מנגנוני הביטחון להימנע מפעולה נחושה נגד המיליציות החמושות.',
#   'mt': 'Among other things, the power vacuum is reflected in the preference of the security mechanisms to avoid a determined action against the armed militias.'},
#  {'src': 'ולראיה, גם בנושאים "רכים", כמו אימוץ מטבע משותף, מתקשות המדינות לשתף פעולה.',
#   'mt': 'And apparently, even on "soft" issues, such as adopting a common currency, it is difficult for countries to cooperate.'},
#  {'src': 'אמות מידה פדרליות בחינוך', 'mt': 'Federal Standards in Education'},
#  {'src': 'באוגוסט 2010 דווח על החלטת משרד הביטחון לרכוש 20 מטוסי F-35A.',
#   'mt': 'In August 2010 it was reported that the Ministry of Defense decided to purchase 20 F-35A aircraft.'},
#  {'src': 'בעידן המלחמה הקרה בגלגולה הקודם, לא תמיד היו סין ורוסיה באותו צד של המתרס.',
#   'mt': 'In the Cold War era in its previous incarnation, China and Russia were not always on the same side of the conflict.'},
#  {'src': 'עבור המערכת פותחו מספר טילי יירוט.',
#   'mt': 'A number of intercept missiles were developed for the system.'},
#  {'src': 'אין תשובה מובנת מאליה לשאלה הראשונה.',
#   'mt': 'There is no obvious answer to the first question.'},
#  {'src': 'במקביל גברו האיומים מצד איראן בעוד ממשל ביידן מגלה עניין רב בדיאלוג עם איראן ובפרט בחזרה להסכם הגרעין.',
#   'mt': 'At the same time, the threats from Iran increased while the Biden administration showed great interest in dialogue with Iran and in particular back to the nuclear agreement.'},
#  {'src': "נשיא ארצות הברית ג'ו ביידן צפוי לערוך ב-13–16 ביולי ביקור במזרח התיכון ובמהלכו יבקר בישראל וברשות הפלסטינית.",
#   'mt': 'US President Joe Biden is expected to pay a visit to the Middle East on July 13-16, during which he will visit Israel and the Palestinian Authority.'},
#  {'src': 'עבור ירדן, לשאלה הפלסטינית יש משמעות קיומית שכן יותר ממחצית מאוכלוסייתה מקורה פלסטיני.',
#   'mt': 'For Jordan, the Palestinian question has existential significance because more than half of its population is of Palestinian origin.'},
#  {'src': 'נשיא ארצות הברית ביידן מתייחס לנסיגה מאפגניסטן בנאום מיוחד, 8 ביולי 2021',
#   'mt': 'US President Biden addresses the withdrawal from Afghanistan in a special speech, July 8, 2021'},
#  {'src': 'להיערכות כזו מרכיבים רבים, אך שניים מהם הם הקריטיים ביותר.',
#   'mt': 'Such a setup has many components, but two of them are the most critical.'},
#  {'src': 'ואכן רוב המתנדבים הערביים בין השנים 1979 - 1992  הגיעו מסעודיה.',
#   'mt': 'Indeed, most of the Arab volunteers between 1979 and 1992 came from Saudi Arabia.'},
#  {'src': 'ראשית, תוואי הצינור הקצר ביותר ממאגרי הגז הישראליים לחוף הטורקי צריך לחצות את האזור הכלכלי הבלעדי של שתי מדינות - לבנון וסוריה.',
#   'mt': 'First, the shortest pipeline route from the Israeli gas reserves to the Turkish coast should cross the exclusive economic zone of two countries - Lebanon and Syria.'},
#  ...]

# %%
model_output = comet_model.predict(data, batch_size=8, gpus=1)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# You are using a CUDA device ('NVIDIA A100 80GB PCIe') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Predicting DataLoader 0: 100%|█████████████████████| 2103/2103 [01:00<00:00, 34.61it/s]

# %%
df_samp['comet_score'] = model_output[0]

# %%
Path('./temp').mkdir(exist_ok=True)
df_samp.to_parquet('./temp/test_commet.parquet')

df_samp[df_samp.comet_score < 0.5][:200].to_html('./temp/bad_lt_0_5.html')
df_samp[df_samp.comet_score > 0.8][:200].to_html('./temp/good_gt_0_8.html')

print('Bad translation ratio', df_samp[df_samp.comet_score < 0.50].shape[0] / df_samp.shape[0])
descrb = df_samp[['comet_score']].describe(percentiles=np.arange(0, 1, 0.1))
print(descrb)

descrb.to_html('./temp/commet_score_quantiles.html')
# Out:
# Bad translation ratio 0.0015458707414233903
#         comet_score
# count  16819.000000
# mean       0.840549
# std        0.054742
# min        0.312532
# 0%         0.312532
# 10%        0.781993
# 20%        0.820015
# 30%        0.838762
# 40%        0.849653
# 50%        0.857665
# 60%        0.864106
# 70%        0.869710
# 80%        0.874933
# 90%        0.881219
# max        0.902790

# %%
df_samp[:100].to_html('./temp/100_random.html')

# %%
for x in range(100):
    df_samp['translation']
# Out:
# 1394    {'en': ' Give her a few hours, she'll be fine....
# 353     {'en': ' The Zionists must be planning somethi...
# 1334    {'en': ' Who sent you here, the guards?', 'he'...
# 906     {'en': ' The door is stuck, but don't worry.',...
# 1290    {'en': ' We have no way of knowing that.', 'he...
#                               ...
# 7475    {'en': ' You are our family, Doron.', 'he': 'א...
# 2236    {'en': ' Abu Ahmed sent me.', 'he': 'אבו אחמד ...
# 8932    {'en': ' We'll talk about that later.', 'he': ...
# 400     {'en': ' I'm sure they will be happy.', 'he': ...
# 3919    {'en': ' thought it would fix her, straighten ...
# Name: translation, Length: 16819, dtype: object
